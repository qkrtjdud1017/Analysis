# %%
from pubg_util import mysql, load_schema, notifier
from sphynx import sphynx, NODE_SMALL, NODE_MEDIUM, NODE_LARGE
from pyspark.sql.functions import *
import pandas as pd

spark = sphynx.get_spark(executor_count=8, app_name='pdu_syp', node_spec=NODE_LARGE)
# Out:
# Spark cluster not assigned. creating a new one...
# Node spec: 8 executors with 48G RAM each
# Job Port 4049 is assigned for requested cluster
# Waiting for Spark master to be available...
# Spark master launched!
# Creating new Spark session, name: pdu_syp...
# Waiting for all executors ready...
# All executors connected!
# Complete! elapsed time: 00:00:25

# %%
sphynx.stop()
# Out:
# Stopping Spark session...
# Destroying Spark cluster...
# Done!
# You can safely ignore the warning message if there is any.

# %%
all_economy_daily = mysql.read_table(spark, "pubg_gi", "all_economy_gcoin_used_by_product_daily")

# %%
all_economy_daily.createOrReplaceTempView("all_economy_daily")

# %%
item_meta_sales = mysql.read_table(spark, "metainfo", "item_meta_sales")
item_meta_sales.createOrReplaceTempView("item_meta_sales")

# %%
q = """
select
	date,
	sum(au) as au
from
	(
	select
		date,
		device,
		platform,
		business_region,
		pubg_region,
		pu_seg_type,
		pu_type,
		user_type,
		au
	from
		all_economy_daily
	where
		date >= '2021-07-26'
		and date <= '2021-08-15'
		and device = 'PC'
	group by
		1,
		2,
		3,
		4,
		5,
		6,
		7,
		8,
		9
	order by
		1) t
group by
	1
order by
	1
"""
daily_au = spark.sql(q)

# %%
daily_au_df = daily_au.toPandas()

# %%
q = """
select
    date,
    sum(pu) as pu,
    (sum(free_gcoin_used) + sum(paid_gcoin_used))/100 as revenue
from all_economy_daily
where date >= "2021-07-26"
    and date <= "2021-08-15"
    and device = "PC"
group by 1
order by 1
"""
daily_summary = spark.sql(q)
daily_summary_df = daily_summary.toPandas()

# %%
daily = pd.merge(daily_au_df, daily_summary_df, on="date")

# %%
daily["pur"] = daily["pu"]/daily["au"]
daily["arpu"] = daily["revenue"]/daily["au"]
daily["arppu"] = daily["revenue"]/daily["pu"]

# %%
daily.to_csv("./data/daily.csv", index=False)

# %%
daily = pd.read_csv("./data/daily.csv")

# %%
daily
# Out:
#           date       au      pu     revenue       pur      arpu      arppu
# 0   2021-07-26  1542625   73187   1244850.8  0.047443  0.806969  17.009179
# 1   2021-07-27  1519156   66310   1119295.0  0.043649  0.736787  16.879732
# 2   2021-07-28  1574783  435823   4223527.0  0.276751  2.681974   9.690923
# 3   2021-07-29  1551455  199913   2158629.2  0.128855  1.391358  10.797843
# 4   2021-07-30  1578927  154796   1772224.0  0.098039  1.122423  11.448771
# 5   2021-07-31  1657376  151180   1839270.0  0.091216  1.109748  12.166093
# 6   2021-08-01  1679359  134404   1672603.6  0.080033  0.995977  12.444597
# 7   2021-08-02  1520773  101832   1285075.2  0.066961  0.845014  12.619562
# 8   2021-08-03  1498145   90475   1102918.0  0.060391  0.736189  12.190307
# 9   2021-08-04  1207607  210611   7428346.6  0.174404  6.151295  35.270459
# 10  2021-08-05  1528680  178914   4706863.8  0.117038  3.079038  26.307968
# 11  2021-08-06  1569815  143904   3309379.6  0.091669  2.108134  22.997134
# 12  2021-08-07  1666156  138652   2905580.2  0.083217  1.743882  20.955920
# 13  2021-08-08  1695350  123750   2387620.6  0.072994  1.408335  19.293904
# 14  2021-08-09  1528122   97687   1844916.6  0.063926  1.207310  18.885999
# 15  2021-08-10  1882298   96624   1831248.6  0.051333  0.972879  18.952316
# 16  2021-08-11  2006851  190472  10698304.4  0.094911  5.330891  56.167334
# 17  2021-08-12  1923887  141017   4948744.4  0.073298  2.572264  35.093247
# 18  2021-08-13  1895042  129730   3943265.8  0.068458  2.080833  30.395944
# 19  2021-08-14  1908342  127060   3359466.4  0.066581  1.760411  26.440000
# 20  2021-08-15  1952299  126472   2952211.0  0.064781  1.512172  23.342803

# %%
q = """
select
	a.*,
	b.product_name,
	b.event_name
from
	(
	select
		date,
		product_id,
		sum(unit_sold) as unit_sold,
		ROW_NUMBER() over (partition by date
	order by
		sum(unit_sold) desc) as row_num
	from
		all_economy_daily
	where
		date >= "2021-07-26"
		and date <= "2021-08-15"
		and device = "PC"
	group by
		1,
		2) a
join (
	select
		product_id,
		product_name,
		event_name
	from
		item_meta_sales
	group by
		1,
		2,
		3) b on
	a.product_id = b.product_id
order by
	date,
	row_num asc
"""
df = spark.sql(q)

# %%
df = df.toPandas()

# %%
df.to_csv("./data/daily_product_rank.csv", index=False)

# %%
df
# Out:
#              date                product_id  unit_sold  row_num  \
# 0      2021-07-26         itemdesc.14100007      32903        2
# 1      2021-07-26  battlepasslevelup.202107      21649        3
# 2      2021-07-26         itemdesc.14100006      11831        4
# 3      2021-07-26         itemdesc.13000312       2922        5
# 4      2021-07-26         itemdesc.13000302       1845        6
# 5      2021-07-26         itemdesc.12010445       1189        7
# 6      2021-07-26         itemdesc.13000311       1178        8
# 7      2021-07-26         itemdesc.45000003       1125        9
# 8      2021-07-26         itemdesc.45000003       1125        9
# 9      2021-07-26         itemdesc.45000003       1125        9
# 10     2021-07-26         itemdesc.45000003       1125        9
# 11     2021-07-26         itemdesc.45000003       1125        9
# 12     2021-07-26         itemdesc.45000003       1125        9
# 13     2021-07-26         itemdesc.45000003       1125        9
# 14     2021-07-26         itemdesc.12010419        813       10
# 15     2021-07-26         itemdesc.12010439        789       11
# 16     2021-07-26         itemdesc.15100002        636       12
# 17     2021-07-26         itemdesc.13000301        612       13
# 18     2021-07-26         itemdesc.13000310        567       14
# 19     2021-07-26         itemdesc.18040101        494       15
# 20     2021-07-26         itemdesc.13000271        383       16
# 21     2021-07-26         itemdesc.16100141        339       17
# 22     2021-07-26         itemdesc.16100270        337       18
# 23     2021-07-26         itemdesc.12010315        333       19
# 24     2021-07-26         itemdesc.12010315        333       19
# 25     2021-07-26         itemdesc.12010315        333       19
# 26     2021-07-26         itemdesc.12010315        333       19
# 27     2021-07-26         itemdesc.12010315        333       19
# 28     2021-07-26         itemdesc.11040058        294       20
# 29     2021-07-26         itemdesc.11050155        290       21
# ...           ...                       ...        ...      ...
# 10507  2021-08-15         itemdesc.11020234          5      265
# 10508  2021-08-15         itemdesc.11030199          5      266
# 10509  2021-08-15         itemdesc.11050154          5      267
# 10510  2021-08-15         itemdesc.11010339          4      268
# 10511  2021-08-15         itemdesc.11020229          4      269
# 10512  2021-08-15         itemdesc.13000252          4      270
# 10513  2021-08-15         itemdesc.11010344          4      271
# 10514  2021-08-15         itemdesc.13000168          4      272
# 10515  2021-08-15         itemdesc.12031069          4      273
# 10516  2021-08-15         itemdesc.13000165          4      274
# 10517  2021-08-15         itemdesc.13000255          3      275
# 10518  2021-08-15         itemdesc.11030198          3      276
# 10519  2021-08-15         itemdesc.13000227          3      277
# 10520  2021-08-15         itemdesc.13000227          3      277
# 10521  2021-08-15         itemdesc.13000227          3      277
# 10522  2021-08-15         itemdesc.11030202          3      278
# 10523  2021-08-15         itemdesc.13000169          3      279
# 10524  2021-08-15         itemdesc.12020026          2      280
# 10525  2021-08-15         itemdesc.11010333          2      281
# 10526  2021-08-15         itemdesc.13000170          2      282
# 10527  2021-08-15         itemdesc.11030205          2      283
# 10528  2021-08-15         itemdesc.13000270          2      284
# 10529  2021-08-15         itemdesc.13000253          2      285
# 10530  2021-08-15         itemdesc.11030195          1      286
# 10531  2021-08-15         itemdesc.11030201          1      287
# 10532  2021-08-15         itemdesc.11030191          1      288
# 10533  2021-08-15         itemdesc.11010357          1      289
# 10534  2021-08-15         itemdesc.11020226          1      290
# 10535  2021-08-15         itemdesc.11030196          1      291
# 10536  2021-08-15         itemdesc.11010355          1      292
#
#                                     product_name  \
# 0           CATACLYSMIC MAGMA - CONTRABAND CRATE
# 1                                 TAEGO Level UP
# 2                 GEAR HEAD I - CONTRABAND CRATE
# 3        VICTORY DANCE - 2 PHUT HON (KAIZ REMIX)
# 4               SURVIVOR PASS: TAEGO WEAPON PACK
# 5                           Son Heung-min - M416
# 6                  SON HEUNG-MIN'S WEAPON BUNDLE
# 7                                Nickname Change
# 8                                Nickname Change
# 9                                Nickname Change
# 10                               Nickname Change
# 11                               Nickname Change
# 12                               Nickname Change
# 13                               Nickname Change
# 14                                    MOZZ's M24
# 15                                     CNH's SLR
# 16                               WEAPON SKIN KEY
# 17      SURVIVOR PASS: TAEGO WEAPON & LEVEL PACK
# 18                 SON HEUNG-MIN'S OUTFIT BUNDLE
# 19                                         Julie
# 20                                   MOZZ'S PACK
# 21                              Victory Dance 41
# 22                              Victory Dance 57
# 23                    Seahorse Cult - Beryl M762
# 24                    Seahorse Cult - Beryl M762
# 25                    Seahorse Cult - Beryl M762
# 26                    Seahorse Cult - Beryl M762
# 27                    Seahorse Cult - Beryl M762
# 28                        Son Heung-min's Gloves
# 29                               MinORu's Hoodie
# ...                                          ...
# 10507                         Ringmaster's Pants
# 10508                          Circus Star Shoes
# 10509                          Hiker's Overshirt
# 10510                      Survivors Biker Shirt
# 10511                      Survivors Biker Jeans
# 10512                        GROOVY GETUP BUNDLE
# 10513                        Circus Star Uniform
# 10514              MANTICORE BLACK MOTOCROSS SET
# 10515               Harlequin - Helmet (Level 1)
# 10516  MANTICORE YELLOW MOTOCROSS AND AKM BUNDLE
# 10517                       GROOVY OUTFIT BUNDLE
# 10518                         Ringmaster's Boots
# 10519             COLORFUL CHAOS WEAPON BUNDLE 1
# 10520             COLORFUL CHAOS WEAPON BUNDLE 1
# 10521             COLORFUL CHAOS WEAPON BUNDLE 1
# 10522            El Solitario Biker Boots (Gray)
# 10523             MANTICORE YELLOW MOTOCROSS SET
# 10524                     "Hippie Soul" Aquarail
# 10525                                Groovy Gown
# 10526                      ENDURO STUNT SUIT SET
# 10527                           Divemaster Boots
# 10528                         HIKER'S OUTFIT SET
# 10529                          HIP OUTFIT BUNDLE
# 10530                      Survivors Biker Shoes
# 10531             El Solitario Biker Boots (Tan)
# 10532                             One Love Shoes
# 10533                            Lobster Costume
# 10534                            Hip Bellbottoms
# 10535                              Hiker's Shoes
# 10536                            Divemaster Suit
#
#                                event_name
# 0                  202107_wsus_apocalypse
# 1                            202107_taego
# 2      202106_wsus_progressive_apocalypse
# 3                       202107_phao_emote
# 4                            202107_taego
# 5                              202107_son
# 6                              202107_son
# 7                              202111_pgc
# 8                               undefined
# 9                             pcs4_reward
# 10                            pcs3_reward
# 11                            pcs2_reward
# 12                            pcs1_reward
# 13                     202109_pcs5_reward
# 14                    202105_cn_streamers
# 15                    202106_cn_streamers
# 16                              undefined
# 17                           202107_taego
# 18                             202107_son
# 19                       202105_nameplate
# 20                    202105_cn_streamers
# 21                        2021_emote_feb2
# 22             202107_summer_season_emote
# 23                              yourshop2
# 24                              yourshop1
# 25                            occult_cnmd
# 26                              yourshop4
# 27                              yourshop3
# 28                             202107_son
# 29                    202105_th_streamers
# ...                                   ...
# 10507                       202105_circus
# 10508                       202105_circus
# 10509                     202105_explorer
# 10510                     202105_explorer
# 10511                     202105_explorer
# 10512                          2021hippie
# 10513                       202105_circus
# 10514                            DIRTBIKE
# 10515                       202105_circus
# 10516                            DIRTBIKE
# 10517                          2021hippie
# 10518                       202105_circus
# 10519                            graffiti
# 10520                           yourshop2
# 10521                           yourshop3
# 10522                  202106_elsolitario
# 10523                            DIRTBIKE
# 10524                          2021hippie
# 10525                          2021hippie
# 10526                            DIRTBIKE
# 10527                 202106_oceanfantasy
# 10528                     202105_explorer
# 10529                          2021hippie
# 10530                     202105_explorer
# 10531                  202106_elsolitario
# 10532                          2021hippie
# 10533                 202106_oceanfantasy
# 10534                          2021hippie
# 10535                     202105_explorer
# 10536                 202106_oceanfantasy
#
# [10537 rows x 6 columns]

# %%
df[df["row_num"] <= 10]
# Out:
#             date                product_id  unit_sold  row_num  \
# 0     2021-07-26         itemdesc.14100007      32903        2
# 1     2021-07-26  battlepasslevelup.202107      21649        3
# 2     2021-07-26         itemdesc.14100006      11831        4
# 3     2021-07-26         itemdesc.13000312       2922        5
# 4     2021-07-26         itemdesc.13000302       1845        6
# 5     2021-07-26         itemdesc.12010445       1189        7
# 6     2021-07-26         itemdesc.13000311       1178        8
# 7     2021-07-26         itemdesc.45000003       1125        9
# 8     2021-07-26         itemdesc.12010419        813       10
# 257   2021-07-27         itemdesc.14100007      29844        2
# 258   2021-07-27  battlepasslevelup.202107      20904        3
# 259   2021-07-27         itemdesc.14100006      10890        4
# 260   2021-07-27         itemdesc.13000312       2899        5
# 261   2021-07-27         itemdesc.13000302       1633        6
# 262   2021-07-27         itemdesc.12010445       1142        7
# 263   2021-07-27         itemdesc.45000003       1089        8
# 264   2021-07-27         itemdesc.13000311       1013        9
# 265   2021-07-27         itemdesc.12010419        772       10
# 513   2021-07-28         itemdesc.14100007      51349        2
# 514   2021-07-28  battlepasslevelup.202107      26353        3
# 515   2021-07-28         itemdesc.14100006      18679        4
# 516   2021-07-28         itemdesc.11050081      11215        5
# 517   2021-07-28         itemdesc.11050129      11017        6
# 518   2021-07-28         itemdesc.13000304      10856        7
# 519   2021-07-28         itemdesc.11050133      10638        8
# 520   2021-07-28         itemdesc.12010221       9773        9
# 521   2021-07-28         itemdesc.12010355       8457       10
# 810   2021-07-29         itemdesc.14100007      37889        2
# 811   2021-07-29  battlepasslevelup.202107      22137        3
# 812   2021-07-29         itemdesc.14100006      14188        4
# ...          ...                       ...        ...      ...
# 4932  2021-08-12         itemdesc.13000318       1492        8
# 4933  2021-08-12         itemdesc.45000003       1375        9
# 4934  2021-08-12         itemdesc.13000302       1347       10
# 5217  2021-08-13         itemdesc.14100008     110872        2
# 5218  2021-08-13  battlepasslevelup.202107      34804        3
# 5219  2021-08-13         itemdesc.14100006      14464        4
# 5220  2021-08-13         itemdesc.14100007       8769        5
# 5221  2021-08-13         itemdesc.13000312       2409        6
# 5222  2021-08-13         itemdesc.13000325       1786        7
# 5223  2021-08-13         itemdesc.13000318       1720        8
# 5224  2021-08-13         itemdesc.45000003       1439        9
# 5225  2021-08-13         itemdesc.13000317       1380       10
# 5508  2021-08-14         itemdesc.14100008      90037        2
# 5509  2021-08-14  battlepasslevelup.202107      41357        3
# 5510  2021-08-14         itemdesc.14100006      13254        4
# 5511  2021-08-14         itemdesc.14100007       7324        5
# 5512  2021-08-14         itemdesc.13000312       2498        6
# 5513  2021-08-14         itemdesc.13000325       1829        7
# 5514  2021-08-14         itemdesc.13000318       1632        8
# 5515  2021-08-14         itemdesc.13000302       1387        9
# 5516  2021-08-14         itemdesc.13000317       1376       10
# 5798  2021-08-15         itemdesc.14100008      77362        2
# 5799  2021-08-15  battlepasslevelup.202107      56497        3
# 5800  2021-08-15         itemdesc.14100006      10791        4
# 5801  2021-08-15         itemdesc.14100007       6654        5
# 5802  2021-08-15         itemdesc.13000312       2560        6
# 5803  2021-08-15         itemdesc.13000325       1610        7
# 5804  2021-08-15         itemdesc.45000003       1410        8
# 5805  2021-08-15         itemdesc.13000318       1400        9
# 5806  2021-08-15         itemdesc.13000302       1365       10
#
#                                  product_name
# 0        CATACLYSMIC MAGMA - CONTRABAND CRATE
# 1                              TAEGO Level UP
# 2              GEAR HEAD I - CONTRABAND CRATE
# 3     VICTORY DANCE - 2 PHUT HON (KAIZ REMIX)
# 4            SURVIVOR PASS: TAEGO WEAPON PACK
# 5                        Son Heung-min - M416
# 6               SON HEUNG-MIN'S WEAPON BUNDLE
# 7                             Nickname Change
# 8                                  MOZZ's M24
# 257      CATACLYSMIC MAGMA - CONTRABAND CRATE
# 258                            TAEGO Level UP
# 259            GEAR HEAD I - CONTRABAND CRATE
# 260   VICTORY DANCE - 2 PHUT HON (KAIZ REMIX)
# 261          SURVIVOR PASS: TAEGO WEAPON PACK
# 262                      Son Heung-min - M416
# 263                           Nickname Change
# 264             SON HEUNG-MIN'S WEAPON BUNDLE
# 265                                MOZZ's M24
# 513      CATACLYSMIC MAGMA - CONTRABAND CRATE
# 514                            TAEGO Level UP
# 515            GEAR HEAD I - CONTRABAND CRATE
# 516                      Rabbit Season Hoodie
# 517                            Floptop Hoodie
# 518                          LONGSKR'S BUNDLE
# 519                 Shiba Crew Hoodie (White)
# 520      [BATTLESTAT] Peace on Earth - Kar98k
# 521               Happy Pew Year - Beryl M762
# 810      CATACLYSMIC MAGMA - CONTRABAND CRATE
# 811                            TAEGO Level UP
# 812            GEAR HEAD I - CONTRABAND CRATE
# ...                                       ...
# 4932                    BLACKPINK MEGA BUNDLE
# 4933                          Nickname Change
# 4934         SURVIVOR PASS: TAEGO WEAPON PACK
# 5217              BUZZKILL - CONTRABAND CRATE
# 5218                           TAEGO Level UP
# 5219           GEAR HEAD I - CONTRABAND CRATE
# 5220     CATACLYSMIC MAGMA - CONTRABAND CRATE
# 5221  VICTORY DANCE - 2 PHUT HON (KAIZ REMIX)
# 5222                           FEMALE FACE 17
# 5223                    BLACKPINK MEGA BUNDLE
# 5224                          Nickname Change
# 5225                JENNIE'S BLACKPINK BUNDLE
# 5508              BUZZKILL - CONTRABAND CRATE
# 5509                           TAEGO Level UP
# 5510           GEAR HEAD I - CONTRABAND CRATE
# 5511     CATACLYSMIC MAGMA - CONTRABAND CRATE
# 5512  VICTORY DANCE - 2 PHUT HON (KAIZ REMIX)
# 5513                           FEMALE FACE 17
# 5514                    BLACKPINK MEGA BUNDLE
# 5515         SURVIVOR PASS: TAEGO WEAPON PACK
# 5516                JENNIE'S BLACKPINK BUNDLE
# 5798              BUZZKILL - CONTRABAND CRATE
# 5799                           TAEGO Level UP
# 5800           GEAR HEAD I - CONTRABAND CRATE
# 5801     CATACLYSMIC MAGMA - CONTRABAND CRATE
# 5802  VICTORY DANCE - 2 PHUT HON (KAIZ REMIX)
# 5803                           FEMALE FACE 17
# 5804                          Nickname Change
# 5805                    BLACKPINK MEGA BUNDLE
# 5806         SURVIVOR PASS: TAEGO WEAPON PACK
#
# [189 rows x 5 columns]

# %% [markdown]
# ## HEIMDAL LOG

# %%
store_explore_items

# %%
log = load_schema.heimdall(spark, 'prod', 'pc-prod', start_date="2021-11-10", end_date="2021-11-13")

# %%
item_log = log.where(col("category") == "store_explore_items")

# %%
item_click_log = item_log.where((col("category") == "store_explore_items") & (col("action") == "click_store_detail"))

# %%
item_click_log.printSchema()
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- category: string (nullable = true)
#  |-- action: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- value: long (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- tracking_id: string (nullable = true)
#  |-- dt: string (nullable = true)
#  |-- hr: string (nullable = true)

# %%
item_click_log.where(col("dt") == "2021-11-10").select("label").distinct().show()
# Out:
# +------------------+
# |             label|
# +------------------+
# | salesitemdesc.427|
# |salesitemdesc.1429|
# |salesitemdesc.1647|
# | salesitemdesc.583|
# |salesitemdesc.1216|
# |salesitemdesc.1627|
# |salesitemdesc.1234|
# |salesitemdesc.1719|
# |salesitemdesc.1638|
# |salesitemdesc.1448|
# |salesitemdesc.1357|
# |salesitemdesc.1746|
# |salesitemdesc.1632|
# |salesitemdesc.1753|
# |salesitemdesc.1695|
# |salesitemdesc.1768|
# |salesitemdesc.1726|
# |salesitemdesc.1346|
# |salesitemdesc.1712|
# |salesitemdesc.1463|
# +------------------+
# only showing top 20 rows

# %%
item_click_log = item_click_log.withColumn("sales_id", split("label", "\.")[1])

# %%
item_meta_sales = mysql.read_table(spark, "metainfo", "item_meta_sales")

# %%
item_click_log = item_click_log.join(item_meta_sales, "sales_id")
item_click_log.where(col("dt") == "2021-11-10").groupBy("product_name").agg(count("*").alias("click_cnt")).orderBy("click_cnt", ascending=False).count()
# Out:
# 341

# %%
click_log_pd = item_click_log.groupBy("dt", "product_id", "product_name").agg(count("*").alias("click_cnt")).toPandas()

# %%
click_log_pd.to_csv("./data/click_log_pd.csv", index=False)

# %%
item_purchase_log = log.where((col("category") == "store_purchase_items") & (col("action") == "click_price_detail"))

# %%
item_purchase_log = item_purchase_log.withColumn("sales_id", split("label", "\.")[1])

# %%
item_purchase_log = item_purchase_log.join(item_meta_sales, "sales_id")

# %%
purchase_log_pd = item_purchase_log.groupBy("dt", "product_id", "product_name").agg(count("*").alias("purchase_cnt")).toPandas()

# %%
purchase_log_pd.to_csv("./data/purchase_log_pd.csv", index=False)

# %%
purchase_log_pd.columns
# Out:
# Index(['dt', 'product_id', 'product_name', 'purchase_cnt'], dtype='object')

# %%
item_tmp = pd.merge(purchase_log_pd, click_log_pd, on=["dt", "product_id", "product_name"])

# %%
item_tmp.head()
# Out:
#            dt         product_id                    product_name  \
# 0  2021-11-13  itemdesc.18100004                            Left
# 1  2021-11-12  itemdesc.12032065  Vivid Pages Backpack (Level 1)
# 2  2021-11-10  itemdesc.11020273        Purrple Periwinkle Pants
# 3  2021-11-10  itemdesc.13000230        GRAFFITI BACKPACK BUNDLE
# 4  2021-11-12  itemdesc.11030194              Pathfinder's Shoes
#
#    purchase_cnt  click_cnt
# 0            46        569
# 1             1        204
# 2            92      13692
# 3            39        944
# 4             2        269

# %%
item_tmp["ctr"] = item_tmp["purchase_cnt"]/item_tmp["click_cnt"]

# %% [markdown]
# 상품상세에서 구매버튼 클릭 , 상품상세 클릭 , 상품상세에서 구매버튼 클릭 / 상품상세 클릭

# %%
item_tmp.groupby("dt").mean()
# Out:
#             purchase_cnt     click_cnt       ctr
# dt
# 2021-11-10    373.002985   6238.988060  0.025378
# 2021-11-11    317.430678   5558.262537  0.029679
# 2021-11-12    524.169591  10167.122807  0.030599
# 2021-11-13    407.500000   7049.032164  0.033092

# %%
bundle = ["itemdesc.13000386", "itemdesc.13000318"]

bundle_tmp = item_tmp[item_tmp.product_id.isin(bundle)]
not_bundle_tmp = item_tmp[~item_tmp.product_id.isin(bundle)]

# %%
bundle_tmp.groupby("dt").mean()
# Out:
#             purchase_cnt  click_cnt       ctr
# dt
# 2021-11-10         701.0    16734.0  0.041891
# 2021-11-11         886.0    23692.0  0.037397
# 2021-11-12       17621.5   241596.0  0.051738
# 2021-11-13        6380.0    97880.0  0.051928

# %%
not_bundle_tmp.groupby("dt").mean()
# Out:
#             purchase_cnt    click_cnt       ctr
# dt
# 2021-11-10    372.020958  6207.565868  0.025329
# 2021-11-11    315.748521  5504.612426  0.029656
# 2021-11-12    423.597059  8805.776471  0.030475
# 2021-11-13    372.367647  6514.732353  0.032981

# %%
item_tmp.to_csv("./data/item_tmp.csv", index=False)

# %% [markdown]
# 2021-08-02 ~ 2021-08-05 for blackpink bundle

# %%
aug_log = load_schema.heimdall(spark, 'prod', 'pc-prod', start_date="2021-08-02", end_date="2021-08-10")

# %%
aug_item_click_log = aug_log.where((col("category") == "store_explore_items") & (col("action") == "click_store_detail"))

# %%
aug_item_click_log = aug_item_click_log.withColumn("sales_id", split("label", "\.")[1])

# %%
aug_item_click_log = aug_item_click_log.join(item_meta_sales, "sales_id")

# %%
aug_click_log_pd = aug_item_click_log.groupBy("dt", "product_id", "product_name").agg(count("*").alias("click_cnt")).toPandas()

# %%
aug_click_log_pd.to_csv("./data/aug_click_log_pd.csv", index=False)

# %%
aug_item_purchase_log = aug_log.where((col("category") == "store_purchase_items") & (col("action") == "click_price_detail"))

# %%
aug_item_purchase_log = aug_item_purchase_log.withColumn("sales_id", split("label", "\.")[1])

# %%
aug_item_purchase_log = aug_item_purchase_log.join(item_meta_sales, "sales_id")

# %%
aug_purchase_log_pd = aug_item_purchase_log.groupBy("dt", "product_id", "product_name").agg(count("*").alias("purchase_cnt")).toPandas()

# %%
aug_purchase_log_pd.to_csv("./data/aug_purchase_log_pd.csv", index=False)

# %%
ctr = pd.merge(aug_purchase_log_pd, aug_click_log_pd, on=["dt", "product_id", "product_name"])

# %%
ctr["ctr"] = ctr["purchase_cnt"]/ctr["click_cnt"]

# %%
aug_bundle_tmp = ctr[ctr.product_id.isin(bundle)]
aug_not_bundle_tmp = ctr[~ctr.product_id.isin(bundle)]

# %%
aug_bundle_tmp.groupby("dt").mean()
# Out:
#             purchase_cnt  click_cnt       ctr
# dt
# 2021-08-04         39011     616936  0.063233
# 2021-08-05         16795     270066  0.062189

# %%
aug_not_bundle_tmp.groupby("dt").mean()
# Out:
#             purchase_cnt     click_cnt       ctr
# dt
# 2021-08-02    426.989209   5295.949640  0.030677
# 2021-08-03    411.340580   5112.898551  0.029611
# 2021-08-04    880.007042  21923.577465  0.029035
# 2021-08-05    657.064286  14151.878571  0.030503

# %%
ctr[ctr['product_id'] == "itemdesc.13000318"]
# Out:
#              dt         product_id           product_name  purchase_cnt  \
# 187  2021-08-05  itemdesc.13000318  BLACKPINK MEGA BUNDLE         16795
# 369  2021-08-04  itemdesc.13000318  BLACKPINK MEGA BUNDLE         39011
#
#      click_cnt       ctr
# 187     270066  0.062189
# 369     616936  0.063233

# %% [markdown]
# ## PU, PUR, ARPPU 등

# %%
from pubg_util import mysql, load_schema, notifier
from sphynx import sphynx, NODE_SMALL, NODE_MEDIUM, NODE_LARGE
from pyspark.sql.functions import *
import pandas as pd

spark = sphynx.get_spark(executor_count=8, app_name='pdu_syp', node_spec=NODE_LARGE)
# Out:
# Spark cluster not assigned. creating a new one...
# Node spec: 8 executors with 48G RAM each
# Job Port 4049 is assigned for requested cluster
# Waiting for Spark master to be available...
# Spark master launched!
# Creating new Spark session, name: pdu_syp...
# Waiting for all executors ready...
# All executors connected!
# Complete! elapsed time: 00:00:26

# %%
from datetime import datetime, timedelta

def load_data_mart(device, start_date, end_date, table_name="cash_mtx", join_with_meta=True):
    """
        load economy data_mart with its corresponding meta
    """
    from datetime import datetime, timedelta
    from pyspark.sql import Window
    from pyspark.sql import functions as F
    from pyspark.sql.types import StringType
    from pubg_util import mysql
    import boto3
    from pubg_util.loader.utils import validate_s3_path
    client = boto3.client('s3')
    bucket = {
        "cash_mtx" : "s3a://pubg-log-labs/data_mart/economy_v2/cash_mtx/{device}/{target_date}",
        "pu_master" : "s3a://pubg-log-labs/data_mart/economy_v2/pu_master/{device}/{target_date}",
        "gcoin_use" : "s3a://pubg-log-labs/data_mart/economy_v3/gcoin_use/{device}/{target_date}",
        "gcoin_topup" : "s3a://pubg-log-labs/data_mart/economy_v3/gcoin_topup/{device}/{target_date}",
        "gcoin_master" : "s3a://pubg-log-labs/data_mart/economy_v3/gcoin_master/{device}/{target_date}",
        "user_master" : "s3a://pubg-log-labs/data_mart/user_master_ver2/{target_date}/{device}"
    }
    meta_name = {
        "cash_mtx" : "meta_cash_mtx",
        "gcoin_use" : "meta_vc_sales_items"
    }
    start_date = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')
    date_list = [(start_date + timedelta(d)).strftime("%Y-%m-%d") for d in range((end_date-start_date).days+1)]
    device_str = device.upper() if table_name=='user_master' else device
    path_list = [bucket[table_name].format(device=device_str, target_date=target_date) for target_date in date_list]
    # load_only valid paths
    valid_path_list = list(filter(lambda path: validate_s3_path(client, path), path_list))
    if len(valid_path_list) == 0:
        message = "no {} data in given period {}-{}".format(table_name, start_date, end_date)
        print(message)
        return None
    if device == 'pc' and table_name == 'cash_mtx':
        df_raw = spark.read.option("mergeSchema", "true").parquet(*valid_path_list)
    elif table_name == 'gcoin_use':
        df_raw = spark.read.option("mergeSchema", "true").parquet(*valid_path_list)
        df_raw_no_salesid = df_raw.where('date >= "2021-07-28" and sales_id is null').toPandas()
        if not df_raw_no_salesid.empty:
            message = 'GCOIN USE data exist: sales_id is null\n{}'.format(df_raw_no_salesid.to_string(index=False))
            print(message)
    else:
        df_raw = spark.read.parquet(*valid_path_list)
 
    missing_dates = list(set(path_list) - set(valid_path_list))
    if len(missing_dates) > 0:
        message = "no data exists in\n" + "\n".join(missing_dates)
        print(message)
    if join_with_meta is False or table_name not in ('cash_mtx', 'gcoin_use'):
        # if it's not cash_mtx or gcoin_use, return raw_df as there are no meta to join with
        return df_raw
    else:
        # load meta_cash_mtx
        meta_raw = (
            mysql.read_table(spark, 'metainfo', meta_name[table_name])
            .withColumnRenamed("platform", "platform_")
            .withColumnRenamed("product_id", "product_id_")
            .withColumnRenamed("price", "price_")
          )
        if table_name == 'gcoin_use':
            meta_raw = meta_raw.where("currency = 'gcoin'")
            df_raw = df_raw \
                .withColumn('is_salesid_exist',
                            F.when(F.col('sales_id').isNull(), F.lit(0)).otherwise(F.lit(1))) \
                .withColumn('sales_id_',
                            F.when(F.col('sales_id').startswith('salesitemdesc'),
                            F.split('sales_id', 'desc.')[1]).otherwise(F.col('sales_id'))) \
                .drop('sales_id')
        if device == 'console' and table_name == 'cash_mtx':
            # join condition
            condition = [
                df_raw.platform == meta_raw.platform_,
                df_raw.product_id == meta_raw.product_id_
            ]
            # join with meta
            # is_paid is hard coded for products that were provided to Stadia Pro users for free during promo period
            df = (
                df_raw
                .join(meta_raw, condition, 'left')
                .withColumn("transaction_id", lit(None).cast(StringType()))
                .withColumn("status", F.lit('Succeeded').cast(StringType()))
                .withColumnRenamed("time", "time_")
                .withColumn("time", F.coalesce(F.col("time_"), F.concat(F.col("date"), F.lit("T00:00:00"))))
                .drop('platform_', 'product_id_', 'time_')
                .withColumn('is_paid',
                    ~(
                        (F.col('product_id').isin(['PUBGPIONEREDITION', 'PUBGBDLDSLEISKIN']))
                    )
                ).where('is_paid')
            )
        else:
            meta_duplicate_count = (
                meta_raw
                .groupBy('product_id_', 'platform_')
                .agg(F.count(F.lit(1)).alias('duplications'))
            )
            window_spec = (
                Window
                .partitionBy('platform_', 'product_id_')
                .orderBy('start_time')
            )
            meta = (
                meta_raw.alias("meta_raw")
                .join(
                    meta_duplicate_count.alias("meta_duplicate_count"),
                    on=['product_id_', 'platform_'],
                    how='left')
                .select("meta_raw.*", "meta_duplicate_count.duplications")
                .withColumn(
                    "next_start_time",
                    F.coalesce(F.lead("start_time").over(window_spec), F.lit('2038-01-19 00:00:00'))
                )
            )
            if table_name == 'gcoin_use':
                condition = (
                (
                    (df_raw.is_salesid_exist == 1)
                    & (
                        (df_raw.platform == meta.platform_)
                        & (df_raw.sales_id_ == meta.sales_id)
                    )
                )
                | ( (df_raw.is_salesid_exist == 0)
                    & (df_raw.platform == meta.platform_)
                    & (df_raw.product_id == meta.product_id_)
                    & (
                        (
                            (df_raw.time >= meta.start_time)
                            & (df_raw.time < meta.next_start_time)
                            & (meta.duplications >= 2)
                        )
                            | (meta.duplications == 1)
                    )
                ))
                # join with meta
                df = (
                    df_raw
                    .join(meta, condition, 'left')
                    .drop('platform_', 'product_id_', 'next_start_time', "duplications")
                )
            else:
                condition = (
                    (df_raw.platform == meta.platform_)
                    & (df_raw.product_id == meta.product_id_)
                    & (
                        (
                            (df_raw.time >= meta.start_time)
                            & (df_raw.time < meta.next_start_time)
                            & (meta.duplications >= 2)
                        )
                            | (meta.duplications == 1)
                    )
                )
                # join with meta
                df = (
                    df_raw.drop('sales_id')
                    .join(meta, condition, 'left')
                    .drop('platform_', 'product_id_', 'next_start_time', "duplications")
                )
        if table_name == 'cash_mtx':
            df = df.withColumn("ingame_revenue", F.col("unit_sold") * F.col("ingame_price"))
 
        return df

# %%
start_date = "2021-07-28"
end_date = "2021-08-10"
device="pc"

# %%
revenue = load_data_mart(start_date=start_date, end_date=end_date, device=device, table_name="gcoin_use")

# %%
user = load_data_mart(start_date=start_date, end_date=end_date, device=device, table_name="user_master").where(col("lastlogindate")>=start_date)

# %%
au = user.groupBy("date").agg(countDistinct("accountid").alias("au"))
au = au.orderBy("date").toPandas()

# %%
au

# %%
bundle_buyer = revenue.where(col("product_id") == "itemdesc.13000318").select("account_id").distinct().toPandas()

# %%
buyer_list = bundle_buyer["account_id"].tolist()

# %%
len(buyer_list)
# Out:
# 53493

# %%
before = revenue.where((col("date") <= "2021-08-03") & (col("account_id").isin(buyer_list)))

# %%
before_buyer = before.select("account_id").distinct().toPandas()["account_id"].tolist()

# %%
after_small = revenue.where((col("date") >= "2021-08-04") & (col("account_id").isin(before_buyer)))
after_small_tmp = after_small.groupBy("date", "account_id").agg(((sum(col("free_use")) + sum(col("paid_use")))/100).alias("spend")).toPandas()

# %%
after_small_tmp.groupby("date")["spend"].mean().reset_index()
# Out:
#          date       spend
# 0  2021-08-04  105.639785
# 1  2021-08-05   80.113080
# 2  2021-08-06   68.119032
# 3  2021-08-07   60.214369
# 4  2021-08-08   53.931137
# 5  2021-08-09   51.588280
# 6  2021-08-10   54.104775

# %%
after = revenue.where((col("date") >= "2021-08-04") & (col("account_id").isin(buyer_list)))

# %%
before_tmp = before.groupBy("date", "account_id").agg(((sum(col("free_use")) + sum(col("paid_use")))/100).alias("spend")).toPandas()

# %%
after_tmp = after.groupBy("date", "account_id").agg(((sum(col("free_use")) + sum(col("paid_use")))/100).alias("spend")).toPandas()

# %%
before_tmp.groupby("date")["spend"].mean().reset_index()
# Out:
#          date      spend
# 0  2021-07-28  24.249319
# 1  2021-07-29  25.988662
# 2  2021-07-30  28.537927
# 3  2021-07-31  32.762055
# 4  2021-08-01  34.071518
# 5  2021-08-02  32.466821
# 6  2021-08-03  33.272715

# %%
after_tmp.groupby("date")["spend"].mean().reset_index()
# Out:
#          date       spend
# 0  2021-08-04  105.483416
# 1  2021-08-05   84.412992
# 2  2021-08-06   74.286418
# 3  2021-08-07   69.978348
# 4  2021-08-08   63.354124
# 5  2021-08-09   62.072433
# 6  2021-08-10   65.497655

# %%
daily.head()
# Out:
#          date       au      pu    revenue       pur      arpu      arppu
# 0  2021-07-26  1542625   73187  1244850.8  0.047443  0.806969  17.009179
# 1  2021-07-27  1519156   66310  1119295.0  0.043649  0.736787  16.879732
# 2  2021-07-28  1574783  435823  4223527.0  0.276751  2.681974   9.690923
# 3  2021-07-29  1551455  199913  2158629.2  0.128855  1.391358  10.797843
# 4  2021-07-30  1578927  154796  1772224.0  0.098039  1.122423  11.448771

# %%
daily_revenue = revenue.groupBy("date").agg(countDistinct("account_id").alias("pu"), ((sum("free_use") + sum("paid_use"))/100).alias("revenue"))

# %%
daily_revenue = daily_revenue.orderBy("date").toPandas()

# %%
au
# Out:
#           date       au
# 0   2021-07-28  1581360
# 1   2021-07-29  2199607
# 2   2021-07-30  2667545
# 3   2021-07-31  3113196
# 4   2021-08-01  3479033
# 5   2021-08-02  3732852
# 6   2021-08-03  3953418
# 7   2021-08-04  4120117
# 8   2021-08-05  4304933
# 9   2021-08-06  4488953
# 10  2021-08-07  4704402
# 11  2021-08-08  4898300
# 12  2021-08-09  5047977
# 13  2021-08-10  5539578

# %%
daily_revenue
# Out:
#           date      pu    revenue
# 0   2021-07-28  154813  2111763.5
# 1   2021-07-29   75863  1079340.6
# 2   2021-07-30   59157   886112.0
# 3   2021-07-31   57430   919635.0
# 4   2021-08-01   51395   836303.8
# 5   2021-08-02   39158   642537.6
# 6   2021-08-03   34987   551464.0
# 7   2021-08-04   73488  3714174.3
# 8   2021-08-05   65742  2353433.9
# 9   2021-08-06   53868  1654689.8
# 10  2021-08-07   52213  1452790.1
# 11  2021-08-08   47407  1193815.3
# 12  2021-08-09   37786   922458.3
# 13  2021-08-10   36835   915630.3
