# %%
from pubg_util import mysql, load_schema, notifier
from sphynx import sphynx, NODE_SMALL, NODE_MEDIUM, NODE_LARGE
from pyspark.sql.functions import *
import pandas as pd
import pickle

spark = sphynx.get_spark(executor_count=4, app_name='pnc', node_spec=NODE_LARGE)
# Out:
# Spark cluster not assigned. creating a new one...
# Node spec: 4 executors with 48G RAM each
# Job Port 4049 is assigned for requested cluster
# Waiting for Spark master to be available...
# Spark master launched!
# Creating new Spark session, name: pnc...
# Waiting for all executors ready...
# All executors connected!
# Complete! elapsed time: 00:00:26

# %%
sphynx.stop()
# Out:
# Stopping Spark session...
# Destroying Spark cluster...
# Done!
# You can safely ignore the warning message if there is any.

# %% [markdown]
# PC
# - 06/08 ~ 06/17
#
# - daily
# - by membership.
# - unit sold = pu
#
# - CurrencyIncreased
#     - 투표 획득 경로

# %%
from pyspark.sql.types import * 

def classify_country(country_os, country_ip):
    if country_os != 'CN':
        return country_ip
    else:
        return country_os

country_type_udf = udf(classify_country, StringType())

meta_region = mysql.read_table(spark, 'metainfo', 'meta_bi_regions')

user = load_data_mart("pc", "2022-06-17", "2022-06-17", "user_master").where(col('lastlogindate') >= "2022-06-08")
user = user.withColumn("country_new", country_type_udf("country_os", "country_ip"))
user = user.join(meta_region, user.country_new == meta_region.country_code_iso2, "left")

# %%
gcoin = load_data_mart("pc", "2022-06-08", "2022-06-17", "gcoin_use").where(col("event_name").like("%pnc%"))
user = user.withColumnRenamed("accountid", "account_id")
membership = load_membership("pubg", "pc", "2022-06-17", "2022-06-17")
user = user.join(membership, "account_id")

# %%
pnc = gcoin.join(user, "account_id", "left")

# %%
region_au = user.groupBy("pubg_region").agg(countDistinct("account_id").alias("au"))

# %%
region_pu = pnc.groupBy("pubg_region").agg(countDistinct("account_id").alias("pu"), sum("free_use").alias("free_use"), sum("paid_use").alias("paid_use"))

# %%
region_paid_pu = pnc.where(col("paid_use") > 0).groupBy("pubg_region").agg(countDistinct("account_id").alias("paid_pu"))

# %%
region_pu = region_pu.join(region_paid_pu, "pubg_region")

# %%
region_kpi = region_au.join(region_pu, "pubg_region").withColumn("pur", col("pu")/col("au")).withColumn("paid_pur", col("paid_pu")/col("au")).withColumn("total_sales", (col("free_use") + col("paid_use"))/100).withColumn("paid_sales", col("paid_use")/100).toPandas()

# %%
region_kpi
# Out:
#   pubg_region       au     pu  free_use  paid_use  paid_pu       pur  \
# 0          CN  3357381  19181  10451930  18127760    15210  0.005713
# 1          NA   139160    792    381780    798300      661  0.005691
# 2          SA   128951    910    671580    684320      635  0.007057
# 3          KR   641019   4859   1926520   5313390     4242  0.007580
# 4         SEA   237245   1824   1108450   1609310     1447  0.007688
# 5          JP    17820    214    117370    201490      173  0.012009
# 6       TW/HK    44664    408    218280    389640      335  0.009135
# 7         CIS   382258   1192    881530    894550      798  0.003118
# 8        EMEA   436769   2578   1499150   2342070     1985  0.005902
# 9          OC    22374    196     89270    202770      175  0.008760
#
#    paid_pur  total_sales  paid_sales
# 0  0.004530     285796.9    181277.6
# 1  0.004750      11800.8      7983.0
# 2  0.004924      13559.0      6843.2
# 3  0.006618      72399.1     53133.9
# 4  0.006099      27177.6     16093.1
# 5  0.009708       3188.6      2014.9
# 6  0.007500       6079.2      3896.4
# 7  0.002088      17760.8      8945.5
# 8  0.004545      38412.2     23420.7
# 9  0.007822       2920.4      2027.7

# %%
membership_au = user.groupBy("membership").agg(countDistinct("account_id").alias("au"))
membership_pu = pnc.groupBy("membership").agg(countDistinct("account_id").alias("pu"), sum("free_use").alias("free_use"), sum("paid_use").alias("paid_use"))
membership_paid_pu = pnc.where(col("paid_use") > 0).groupBy("membership").agg(countDistinct("account_id").alias("paid_pu"))
membership_pu = membership_pu.join(membership_paid_pu, "membership")

membership_kpi = membership_au.join(membership_pu, "membership").withColumn("pur", col("pu")/col("au")).withColumn("paid_pur", col("paid_pu")/col("au")).withColumn("total_sales", (col("free_use") + col("paid_use"))/100).withColumn("paid_sales", col("paid_use")/100).toPandas()

# %%
membership_kpi
# Out:
#   membership       au     pu  free_use  paid_use  paid_pu       pur  paid_pur  \
# 0       plus   144323   3378   1888720   3144500     2715  0.023406  0.018812
# 1      basic  2157774    993    398450   1081120      873  0.000460  0.000405
# 2     legacy  3105901  27783  15058690  26337980    22073  0.008945  0.007107
#
#    total_sales  paid_sales
# 0      50332.2     31445.0
# 1      14795.7     10811.2
# 2     413966.7    263379.8

# %% [markdown]
# - Total G-Coin: 47,909,460 G-Coin
# - Paid G-Coin: 30,563,600 G-Coin

# %% [markdown]
# - pu = 32154
# - paid pu = 25661

# %%
env = 'live'
log_type = 'PickStatusChanged'

pick_status = load_schema.lobby(spark, "pc", env, log_type, "2022-06-08", "2022-06-17")

# %%
env = 'live'
log_type = 'CurrencyIncreased'

currency = load_schema.lobby(spark, "pc", env, log_type, "2022-06-08", "2022-06-17")

# %%
currency = currency.withColumnRenamed("AccountId", "account_id")
user_tmp = user.select("account_id", "membership", "pubg_region")
currency_pnc = currency.where((col("Currency").like("%pickem%")) & ((col("Reason") != "inventory-cleanup"))).join(user_tmp, "account_id", "left")

# %%
currency_pnc = currency_pnc.where((~col("Currency").isin(["currencydesc.pickem.votingcoupon.p.pickem202102", "currencydesc.pickem.votingcoupon.p.pickem202101"])))

# %%
daily_currency = currency_pnc.withColumn("case", when(col("amount") > 0, "+").otherwise("-")).groupBy("date", "case").agg(sum("Amount").alias("amount"), countDistinct("account_id").alias("user_cnt")).orderBy("date", "case").toPandas()

# %%
daily_currency
# Out:
#           date case  amount  user_cnt
# 0   2022-06-08    +  556391    505991
# 1   2022-06-08    - -299876    280634
# 2   2022-06-09    +  317449    298900
# 3   2022-06-09    - -222004    210487
# 4   2022-06-10    +  218165    204089
# 5   2022-06-10    - -152008    142489
# 6   2022-06-11    +  197544    184741
# 7   2022-06-11    - -139728    130864
# 8   2022-06-12    +  153234    142615
# 9   2022-06-12    - -111381    103349
# 10  2022-06-13    +   98747     91250
# 11  2022-06-13    -  -76008     69655
# 12  2022-06-14    +   82881     75898
# 13  2022-06-14    -  -65246     58813
# 14  2022-06-15    +   83596     75687
# 15  2022-06-15    -  -70595     62105
# 16  2022-06-16    +  106329     91121
# 17  2022-06-16    -  -99328     77942
# 18  2022-06-17    +   24836     21810
# 19  2022-06-17    -  -23813     18565

# %%
daily_currency_reason = currency_pnc.withColumn("case", when(col("amount") > 0, "+").otherwise("-")).groupBy("date", "case", "Reason").agg(sum("Amount").alias("amount"), countDistinct("account_id").alias("user_cnt")).orderBy("date", "case").toPandas()

# %%
daily_currency_reason.head()
# Out:
#          date case                       Reason  amount  user_cnt
# 0  2022-06-08    +       commercial-word-redeem       5         5
# 1  2022-06-08    +  outgameevent-mission-reward  502331    502331
# 2  2022-06-08    +                buy-cash-item   54055     10811
# 3  2022-06-08    -                  pickem-pick -299876    280634
# 4  2022-06-09    +                   open-crate       1         1

# %%
daily_currency_reason.to_csv("./daily_currency_reason.csv", index=False)

# %%
currency_pnc.withColumn("case", when(col("amount") > 0, "+").otherwise("-")).groupBy("case").agg(countDistinct("account_id").alias("user_cnt")).show()
# Out:
# +----+--------+
# |case|user_cnt|
# +----+--------+
# |   +| 1654784|
# |   -| 1123819|
# +----+--------+

# %%
voting_coupon_by_user = currency_pnc.withColumn("case", when(col("amount") > 0, "+").otherwise("-")).groupBy("case", "account_id").agg(sum("Amount").alias("amount")).toPandas()

# %%
voting_coupon_by_user.groupby("case")["amount"].mean()
# Out:
# case
# +    1.111427
# -   -1.121165
# Name: amount, dtype: float64

# %%
pickem_region = currency_pnc.groupBy("pubg_region", "Currency", "Reason").agg(sum("Amount").alias("amount")).toPandas()

# %%
pickem_region.groupby(["pubg_region", "Reason"])["amount"].sum().reset_index()
# Out:
#    pubg_region                       Reason   amount
# 0          CIS                buy-cash-item     5960
# 1          CIS       commercial-word-redeem     4827
# 2          CIS                   open-crate       10
# 3          CIS  outgameevent-mission-reward   117321
# 4          CIS                  pickem-pick   -76710
# 5          CIS        promotion-code-redeem       23
# 6           CN                buy-cash-item    95905
# 7           CN       commercial-word-redeem    13424
# 8           CN                   open-crate       55
# 9           CN  outgameevent-mission-reward  1070121
# 10          CN                  pickem-pick  -824738
# 11          CN        promotion-code-redeem       70
# 12        EMEA                buy-cash-item    12890
# 13        EMEA       commercial-word-redeem     3968
# 14        EMEA                   open-crate      115
# 15        EMEA  outgameevent-mission-reward   114847
# 16        EMEA                  pickem-pick   -81743
# 17        EMEA        promotion-code-redeem       96
# 18          JP                buy-cash-item     1070
# 19          JP       commercial-word-redeem      213
# 20          JP  outgameevent-mission-reward     3659
# 21          JP                  pickem-pick    -3197
# 22          JP        promotion-code-redeem        1
# 23          KR                buy-cash-item    24295
# 24          KR       commercial-word-redeem     1820
# 25          KR                   open-crate        1
# 26          KR  outgameevent-mission-reward   190653
# 27          KR                  pickem-pick  -153782
# 28          KR        promotion-code-redeem        6
# 29          NA                buy-cash-item     3960
# 30          NA       commercial-word-redeem      179
# 31          NA                   open-crate       30
# 32          NA  outgameevent-mission-reward    24552
# 33          NA                  pickem-pick   -16825
# 34          NA        promotion-code-redeem       36
# 35          OC                buy-cash-item      980
# 36          OC       commercial-word-redeem      149
# 37          OC                   open-crate        5
# 38          OC  outgameevent-mission-reward     5923
# 39          OC                  pickem-pick    -4554
# 40          OC        promotion-code-redeem        9
# 41          SA                buy-cash-item     4550
# 42          SA       commercial-word-redeem     1431
# 43          SA                   open-crate      150
# 44          SA  outgameevent-mission-reward    35921
# 45          SA                  pickem-pick   -26966
# 46          SA        promotion-code-redeem       98
# 47         SEA                buy-cash-item     9120
# 48         SEA       commercial-word-redeem     3891
# 49         SEA                   open-crate      590
# 50         SEA  outgameevent-mission-reward    70416
# 51         SEA                  pickem-pick   -59975
# 52         SEA        promotion-code-redeem       80
# 53       TW/HK                buy-cash-item     2040
# 54       TW/HK       commercial-word-redeem      841
# 55       TW/HK                   open-crate       40
# 56       TW/HK  outgameevent-mission-reward    12802
# 57       TW/HK                  pickem-pick   -11497
# 58       TW/HK        promotion-code-redeem       22
# 59   Undefined  outgameevent-mission-reward        1

# %%
pickem_region.to_csv("./pickem_region.csv", index=False)

# %%
pickem_region.groupby("pubg_region")["amount"].sum().reset_index()
# Out:
#    pubg_region  amount
# 0          CIS   51431
# 1           CN  354837
# 2         EMEA   50173
# 3           JP    1746
# 4           KR   62993
# 5           NA   11932
# 6           OC    2512
# 7           SA   15184
# 8          SEA   24122
# 9        TW/HK    4248
# 10   Undefined       1

# %%
pickem_region[pickem_region.amount > 0].groupby("pubg_region")["amount"].sum().reset_index()
# Out:
#    pubg_region   amount
# 0          CIS   128141
# 1           CN  1179575
# 2         EMEA   131916
# 3           JP     4943
# 4           KR   216775
# 5           NA    28757
# 6           OC     7066
# 7           SA    42150
# 8          SEA    84097
# 9        TW/HK    15745
# 10   Undefined        1

# %%
pickem_region[pickem_region.amount < 0].groupby("pubg_region")["amount"].sum().reset_index()
# Out:
#   pubg_region  amount
# 0         CIS  -76710
# 1          CN -824738
# 2        EMEA  -81743
# 3          JP   -3197
# 4          KR -153782
# 5          NA  -16825
# 6          OC   -4554
# 7          SA  -26966
# 8         SEA  -59975
# 9       TW/HK  -11497

# %%
currency_pnc.withColumn("case", when(col("amount") > 0, "+").otherwise("-")).groupBy("pubg_region", "case").agg(sum("Amount").alias("amount"), countDistinct("account_id").alias("user_cnt")).orderBy("pubg_region", "case").toPandas()
# Out:
#    pubg_region case   amount  user_cnt
# 0          CIS    +   128141    117717
# 1          CIS    -   -76710     68508
# 2           CN    +  1179575   1074855
# 3           CN    -  -824738    751190
# 4         EMEA    +   131916    115698
# 5         EMEA    -   -81743     69327
# 6           JP    +     4943      3750
# 7           JP    -    -3197      2176
# 8           KR    +   216775    191752
# 9           KR    -  -153782    134204
# 10          NA    +    28757     24813
# 11          NA    -   -16825     14070
# 12          OC    +     7066      5994
# 13          OC    -    -4554      3706
# 14          SA    +    42150     36158
# 15          SA    -   -26966     22135
# 16         SEA    +    84097     71089
# 17         SEA    -   -59975     49328
# 18       TW/HK    +    15745     12957
# 19       TW/HK    -   -11497      9175
# 20   Undefined    +        1         1

# %%
currency_pnc.withColumn("case", when(col("amount") > 0, "+").otherwise("-")).groupBy("membership", "case")\
    .agg(sum("Amount").alias("amount"), countDistinct("account_id").alias("user_cnt")).orderBy("membership", "case").toPandas()
# Out:
#   membership case   amount  user_cnt
# 0      basic    +   313540    307385
# 1      basic    -  -169593    165644
# 2     legacy    +  1417227   1256605
# 3     legacy    - -1010951    891406
# 4       plus    +   108399     90794
# 5       plus    -   -79443     66769

# %%
currency_increased = mysql.read_table(spark, "labs", "hourly_currency_increased").where((col("datetime") >= "2022-06-08") & (col("datetime") <= "2022-06-17"))

# %%
currency_increased.where((col("Currency").like("%pickem%")) & (col("Reason") != "inventory-cleanup")).show(truncate=False)
# Out:
# +-------------------+-----------------------------------------------+---------------------------+--------+-------------------+------------------+
# |datetime           |Currency                                       |Reason                     |Provider|regdatetime        |currency_increased|
# +-------------------+-----------------------------------------------+---------------------------+--------+-------------------+------------------+
# |2022-06-08 02:00:00|currencydesc.pickem.votingcoupon.p             |pickem-pick                |steam   |2022-06-08 04:23:05|-1                |
# |2022-06-08 03:00:00|currencydesc.pickem.votingcoupon.p.pickem202206|buy-cash-item              |kakao   |2022-06-08 04:23:05|5                 |
# |2022-06-08 02:00:00|currencydesc.pickem.votingcoupon.p.pickem202206|buy-cash-item              |steam   |2022-06-08 04:23:05|5                 |
# |2022-06-08 05:00:00|currencydesc.pickem.votingcoupon.p             |pickem-pick                |kakao   |2022-06-08 06:37:38|-5                |
# |2022-06-08 05:00:00|currencydesc.pickem.votingcoupon.foc           |outgameevent-mission-reward|steam   |2022-06-08 06:37:38|1                 |
# |2022-06-08 05:00:00|currencydesc.pickem.votingcoupon.foc           |pickem-pick                |steam   |2022-06-08 06:37:38|-1                |
# |2022-06-08 05:00:00|currencydesc.pickem.votingcoupon.p             |pickem-pick                |steam   |2022-06-08 06:37:38|-3                |
# |2022-06-08 04:00:00|currencydesc.pickem.votingcoupon.foc           |outgameevent-mission-reward|steam   |2022-06-08 06:37:38|1                 |
# |2022-06-08 05:00:00|currencydesc.pickem.votingcoupon.p.pickem202206|buy-cash-item              |steam   |2022-06-08 06:37:38|5                 |
# |2022-06-08 04:00:00|currencydesc.pickem.votingcoupon.foc           |commercial-word-redeem     |steam   |2022-06-08 06:37:38|1                 |
# |2022-06-08 06:00:00|currencydesc.pickem.votingcoupon.p.pickem202206|buy-cash-item              |steam   |2022-06-08 07:27:34|45                |
# |2022-06-08 06:00:00|currencydesc.pickem.votingcoupon.foc           |outgameevent-mission-reward|kakao   |2022-06-08 07:27:34|1                 |
# |2022-06-08 06:00:00|currencydesc.pickem.votingcoupon.foc           |outgameevent-mission-reward|steam   |2022-06-08 07:27:34|1                 |
# |2022-06-08 06:00:00|currencydesc.pickem.votingcoupon.foc           |pickem-pick                |kakao   |2022-06-08 07:27:34|-1                |
# |2022-06-08 06:00:00|currencydesc.pickem.votingcoupon.p             |pickem-pick                |steam   |2022-06-08 07:27:34|-4                |
# |2022-06-08 07:00:00|currencydesc.pickem.votingcoupon.p.pickem202206|buy-cash-item              |kakao   |2022-06-08 08:27:36|355               |
# |2022-06-08 07:00:00|currencydesc.pickem.votingcoupon.p.pickem202206|buy-cash-item              |steam   |2022-06-08 08:27:36|5590              |
# |2022-06-08 07:00:00|currencydesc.pickem.votingcoupon.foc           |outgameevent-mission-reward|kakao   |2022-06-08 08:27:36|33                |
# |2022-06-08 07:00:00|currencydesc.pickem.votingcoupon.foc           |outgameevent-mission-reward|steam   |2022-06-08 08:27:36|3049              |
# |2022-06-08 07:00:00|currencydesc.pickem.votingcoupon.p             |pickem-pick                |kakao   |2022-06-08 08:27:36|-132              |
# +-------------------+-----------------------------------------------+---------------------------+--------+-------------------+------------------+
# only showing top 20 rows

# %%
pickem = currency_increased.where((col("Currency").like("%pickem%")) & (col("Reason") != "inventory-cleanup")).groupBy("Currency", "Reason").agg(sum("currency_increased")).toPandas()

# %%
pickem.loc[1:8]
# Out:
#                                           Currency  \
# 1               currencydesc.pickem.votingcoupon.p
# 2       currencydesc.pickem.votingcoupon.p.pgc2021
# 3             currencydesc.pickem.votingcoupon.foc
# 4  currencydesc.pickem.votingcoupon.p.pickem202206
# 5             currencydesc.pickem.votingcoupon.foc
# 6  currencydesc.pickem.votingcoupon.p.pickem202206
# 7             currencydesc.pickem.votingcoupon.foc
# 8             currencydesc.pickem.votingcoupon.foc
#
#                         Reason  sum(currency_increased)
# 1                  pickem-pick                  -116307
# 2                   open-crate                        1
# 3                  pickem-pick                 -1119226
# 4                   open-crate                      520
# 5  outgameevent-mission-reward                  1627938
# 6                buy-cash-item                   157565
# 7       commercial-word-redeem                    26994
# 8        promotion-code-redeem                      377

# %%
pickem
# Out:
#                                           Currency  \
# 0  currencydesc.pickem.votingcoupon.p.pickem202102
# 1               currencydesc.pickem.votingcoupon.p
# 2       currencydesc.pickem.votingcoupon.p.pgc2021
# 3             currencydesc.pickem.votingcoupon.foc
# 4  currencydesc.pickem.votingcoupon.p.pickem202206
# 5             currencydesc.pickem.votingcoupon.foc
# 6  currencydesc.pickem.votingcoupon.p.pickem202206
# 7             currencydesc.pickem.votingcoupon.foc
# 8             currencydesc.pickem.votingcoupon.foc
# 9  currencydesc.pickem.votingcoupon.p.pickem202101
#
#                         Reason  sum(currency_increased)
# 0                   open-crate                        1
# 1                  pickem-pick                  -116307
# 2                   open-crate                        1
# 3                  pickem-pick                 -1119226
# 4                   open-crate                      520
# 5  outgameevent-mission-reward                  1627938
# 6                buy-cash-item                   157565
# 7       commercial-word-redeem                    26994
# 8        promotion-code-redeem                      377
# 9                   open-crate                        5
