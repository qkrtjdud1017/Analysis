# %%
from pubg_util import mysql, load_schema, notifier
from sphynx import sphynx, NODE_SMALL, NODE_MEDIUM, NODE_LARGE
from pyspark.sql.functions import *

spark = sphynx.get_spark(executor_count=4, app_name='pdu_syp2', node_spec=NODE_MEDIUM)
# Out:
# WARN: Spark session already exists with 8 executors.
# If you want to have 4 executors, please call sphynx.stop() and recreate the session.

# %% [markdown]
# ## CONSOLE

# %%
start_date = '2021-09-11'
end_date = '2021-10-17'

# %%
device='console'
user = load_data_mart(start_date=start_date, end_date=end_date, device=device, table_name='user_master')
gcoin = load_data_mart(start_date=start_date, end_date=end_date, device=device, table_name='gcoin_use')

# %%
#pc 와 비교 위한 
device='pc'
user_pc = load_data_mart(start_date=start_date, end_date=end_date, device=device, table_name='user_master')
gcoin_pc = load_data_mart(start_date=start_date, end_date=end_date, device=device, table_name='gcoin_use')

# %%
user.count()
# Out:
# 1059637377

# %%
gcoin.count()
# Out:
# 264063

# %%
au = user.where('lastlogindate >= date').groupBy('date').agg(countDistinct('accountid').alias('au')).orderBy('date')
pu = gcoin.groupBy('date').agg(countDistinct('account_id').alias('pu'), sum('price').alias('price_sum')).orderBy('date')

# %%
au_pc = user_pc.where('lastlogindate >= date').groupBy('date').agg(countDistinct('accountid').alias('au')).orderBy('date')
pu_pc = gcoin_pc.groupBy('date').agg(countDistinct('account_id').alias('pu'), sum('price').alias('price_sum')).orderBy('date')

# %%
au.show()
# Out:
# +----------+------+
# |      date|    au|
# +----------+------+
# |2021-09-11|161657|
# |2021-09-12|171053|
# |2021-09-13|149841|
# |2021-09-14|149412|
# |2021-09-15|155129|
# |2021-09-16|133025|
# |2021-09-17|151768|
# |2021-09-18|167920|
# |2021-09-19|173939|
# |2021-09-20|155163|
# |2021-09-21|151731|
# |2021-09-22|149057|
# |2021-09-23|147480|
# |2021-09-24|146918|
# |2021-09-25|159965|
# |2021-09-26|166791|
# |2021-09-27|146902|
# |2021-09-28|144300|
# |2021-09-29|144309|
# |2021-09-30|142495|
# +----------+------+
# only showing top 20 rows

# %%
pu.show()
# Out:
# +----------+----+---------+
# |      date|  pu|price_sum|
# +----------+----+---------+
# |2021-09-11|2001|  3284330|
# |2021-09-12|2187|  3647140|
# |2021-09-13|1625|  2325170|
# |2021-09-14|1457|  2005960|
# |2021-09-15|1566|  2793980|
# |2021-09-16|9503| 18116390|
# |2021-09-17|8646| 15968160|
# |2021-09-18|7617| 14124660|
# |2021-09-19|5897|  9276490|
# |2021-09-20|3997|  6292430|
# |2021-09-21|3385|  5225210|
# |2021-09-22|3033|  4695110|
# |2021-09-23|2886|  4156800|
# |2021-09-24|2727|  4166310|
# |2021-09-25|3364|  5044800|
# |2021-09-26|3255|  4650440|
# |2021-09-27|2400|  3587350|
# |2021-09-28|2267|  3304870|
# |2021-09-29|3974|  4534550|
# |2021-09-30|3314|  4058180|
# +----------+----+---------+
# only showing top 20 rows

# %%
pur = au.join(pu, 'date').withColumn('pur', col('pu')/col('au')) \
                   .withColumn('ARPU', col('price_sum')/col('au')) \
                   .withColumn('ARPPU', col('price_sum')/col('pu')).orderBy('date')

# %%
pur_pc = au_pc.join(pu_pc, 'date').withColumn('pur', col('pu')/col('au')) \
                   .withColumn('ARPU', col('price_sum')/col('au')) \
                   .withColumn('ARPPU', col('price_sum')/col('pu')).orderBy('date')

# %%
pur.show()
# Out:
# +----------+------+----+---------+--------------------+------------------+------------------+
# |      date|    au|  pu|price_sum|                 pur|              ARPU|             ARPPU|
# +----------+------+----+---------+--------------------+------------------+------------------+
# |2021-09-11|161657|2001|  3284330|0.012378059719034747|20.316658109453968| 1641.344327836082|
# |2021-09-12|171053|2187|  3647140|0.012785510923514935|21.321695614809446|1667.6451760402379|
# |2021-09-13|149841|1625|  2325170|0.010844828851916365|15.517581970221768|1430.8738461538462|
# |2021-09-14|149412|1457|  2005960|0.009751559446363077| 13.42569539260568| 1376.774193548387|
# |2021-09-15|155129|1566|  2793980|0.010094824307511813| 18.01068787911996|1784.1507024265645|
# |2021-09-16|133025|9503| 18116390| 0.07143769968051118|136.18785942492013| 1906.386404293381|
# |2021-09-17|151768|8646| 15968160| 0.05696853091560803|105.21427441884983|1846.8841082581541|
# |2021-09-18|167920|7617| 14124660| 0.04536088613625536| 84.11541210100047| 1854.359984245766|
# |2021-09-19|173939|5897|  9276490| 0.03390269002351399|53.331857720235256|1573.0863150754622|
# |2021-09-20|155163|3997|  6292430|0.025760007218215683| 40.55367581188814|1574.2882161621217|
# |2021-09-21|151731|3385|  5225210|0.022309218287627445|34.437326584547655|1543.6366322008862|
# |2021-09-22|149057|3033|  4695110| 0.02034792059413513|31.498755509637252|1548.0085723705902|
# |2021-09-23|147480|2886|  4156800|0.019568755085435312|28.185516680227828|1440.3326403326403|
# |2021-09-24|146918|2727|  4166310|0.018561374372098722|28.358063681781672|1527.7997799779978|
# |2021-09-25|159965|3364|  5044800|0.021029600225049228| 31.53689869658988|1499.6432818073722|
# |2021-09-26|166791|3255|  4650440| 0.01951544148065543|27.881840147250152|1428.7066052227342|
# |2021-09-27|146902|2400|  3587350| 0.01633742222706294|24.420021510939264|1494.7291666666667|
# |2021-09-28|144300|2267|  3304870| 0.01571032571032571|22.902772002772004|1457.8164975738862|
# |2021-09-29|144309|3974|  4534550| 0.02753812998496282| 31.42250310098469|1141.0543532964268|
# |2021-09-30|142495|3314|  4058180|0.023256956384434542|28.479455419488403|1224.5564272782137|
# +----------+------+----+---------+--------------------+------------------+------------------+
# only showing top 20 rows

# %%
import pandas as pd

pur_pd = pur.toPandas().round(3)

# %%
pur_pc_pd = pur_pc.toPandas().round(3)
pur_pc_pd.to_csv('pur_pc_pd.csv', index=False)

# %%
pur_pd.to_csv('pur_pd.csv', index=False)

# %%
pur_pd
# Out:
#           date      au    pu  price_sum    pur     ARPU     ARPPU
# 0   2021-09-11  161657  2001    3284330  0.012   20.317  1641.344
# 1   2021-09-12  171053  2187    3647140  0.013   21.322  1667.645
# 2   2021-09-13  149841  1625    2325170  0.011   15.518  1430.874
# 3   2021-09-14  149412  1457    2005960  0.010   13.426  1376.774
# 4   2021-09-15  155129  1566    2793980  0.010   18.011  1784.151
# 5   2021-09-16  133025  9503   18116390  0.071  136.188  1906.386
# 6   2021-09-17  151768  8646   15968160  0.057  105.214  1846.884
# 7   2021-09-18  167920  7617   14124660  0.045   84.115  1854.360
# 8   2021-09-19  173939  5897    9276490  0.034   53.332  1573.086
# 9   2021-09-20  155163  3997    6292430  0.026   40.554  1574.288
# 10  2021-09-21  151731  3385    5225210  0.022   34.437  1543.637
# 11  2021-09-22  149057  3033    4695110  0.020   31.499  1548.009
# 12  2021-09-23  147480  2886    4156800  0.020   28.186  1440.333
# 13  2021-09-24  146918  2727    4166310  0.019   28.358  1527.800
# 14  2021-09-25  159965  3364    5044800  0.021   31.537  1499.643
# 15  2021-09-26  166791  3255    4650440  0.020   27.882  1428.707
# 16  2021-09-27  146902  2400    3587350  0.016   24.420  1494.729
# 17  2021-09-28  144300  2267    3304870  0.016   22.903  1457.816
# 18  2021-09-29  144309  3974    4534550  0.028   31.423  1141.054
# 19  2021-09-30  142495  3314    4058180  0.023   28.479  1224.556
# 20  2021-10-01  141796  2948    3834060  0.021   27.039  1300.563
# 21  2021-10-02  156203  3460    4698350  0.022   30.078  1357.905
# 22  2021-10-03  164961  3331    4129620  0.020   25.034  1239.754
# 23  2021-10-04  144553  2379    2962120  0.016   20.492  1245.111
# 24  2021-10-05  141294  2170    2790440  0.015   19.749  1285.917
# 25  2021-10-06  137383  2009    2523990  0.015   18.372  1256.341
# 26  2021-10-07  134548  1970    2460980  0.015   18.291  1249.228
# 27  2021-10-08  134849  2108    2823730  0.016   20.940  1339.530
# 28  2021-10-09  149019  2485    3422980  0.017   22.970  1377.457
# 29  2021-10-10  156834  2520    3278980  0.016   20.907  1301.183
# 30  2021-10-11  145008  1975    2505270  0.014   17.277  1268.491
# 31  2021-10-12  138054  1666    2227850  0.012   16.138  1337.245
# 32  2021-10-13  133279  1700    2192340  0.013   16.449  1289.612
# 33  2021-10-14  118896  3835   11851660  0.032   99.681  3090.394
# 34  2021-10-15  132379  3797    9671980  0.029   73.063  2547.269
# 35  2021-10-16  147398  3735    8234910  0.025   55.869  2204.795
# 36  2021-10-17  155364  3413    6486200  0.022   41.748  1900.439

# %%
gcoin.where("lower(product_name) like '%bundle%' ").groupby('product_name').count().orderBy('count', ascending=False).show()
# Out:
# +--------------------+-----+
# |        product_name|count|
# +--------------------+-----+
# |  MOON RABBIT BUNDLE| 3915|
# |B.A.S.A. BUNNY BU...| 2464|
# |PCS5 ULTIMATE BUNDLE| 1212|
# |  MOON SEEKER BUNDLE|  964|
# |SPACE BUNNY ULTIM...|  737|
# |JISOO'S BLACKPINK...|  634|
# |ROSÉ'S BLACKPINK ...|  558|
# |JENNIE'S BLACKPIN...|  484|
# |NO STRINGS ATTACH...|  237|
# |SON HEUNG-MIN'S C...|  228|
# |BLACKPINK MEGA BU...|  215|
# |MARQUIS DE FOX BU...|  212|
# |  FANCY BERYL BUNDLE|  210|
# |VIGILANTE BACKPAC...|  177|
# |SPIKED SWEETNESS ...|  173|
# |VIGILANTE HELMET ...|  167|
# |LISA'S BLACKPINK ...|  166|
# |RACY REINDEER BUNDLE|  155|
# |    LONGSKR'S BUNDLE|  150|
# |  STAY FROSTY BUNDLE|  142|
# +--------------------+-----+
# only showing top 20 rows

# %%
gcoin.where("lower(product_name) like '%bundle%' and price >= 3000").groupBy('product_name').count().orderBy('count', ascending=False).show(truncate=False)
# Out:
# +---------------------------+-----+
# |product_name               |count|
# +---------------------------+-----+
# |PCS5 ULTIMATE BUNDLE       |1212 |
# |SPACE BUNNY ULTIMATE BUNDLE|737  |
# |BLACKPINK MEGA BUNDLE      |215  |
# +---------------------------+-----+

# %%
gcoin.where("product_name like '%emote%' ").count()
# Out:
# 0

# %%
daily_gcoin_pd = gcoin.groupBy('date', 'account_id').agg(sum('price').alias('gcoin_daily_use'), 
                                        min('price').alias('min_gcoin'), 
                                        avg('price').alias('avg_gcoin'), 
                                        max('price').alias('max_gcoin'),
                                        countDistinct('transaction_id').alias('trans_time')).toPandas()

# %%
daily_gcoin_pd.describe()
# Out:
#        gcoin_daily_use      min_gcoin      avg_gcoin      max_gcoin  \
# count    120602.000000  120602.000000  120602.000000  120602.000000
# mean       1636.405615     628.214789     764.647735     961.184723
# std        2877.812303     654.229239     675.177852     912.394694
# min         100.000000     100.000000     100.000000     100.000000
# 25%         500.000000     200.000000     275.000000     300.000000
# 50%         990.000000     500.000000     595.000000     990.000000
# 75%        1800.000000     990.000000     990.000000    1190.000000
# max      116400.000000    9900.000000    9900.000000    9900.000000
#
#           trans_time
# count  120602.000000
# mean        2.189541
# std         2.612268
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        86.000000

# %%
account_cnt_500 = daily_gcoin_pd[(daily_gcoin_pd.gcoin_daily_use >= 500) & (daily_gcoin_pd.gcoin_daily_use < 1000)].groupby('date')['account_id'].count().reset_index(name='500').sort_values('date')

# %%
account_cnt_3000 = daily_gcoin_pd[(daily_gcoin_pd.gcoin_daily_use >= 3000) & (daily_gcoin_pd.gcoin_daily_use < 3500)].groupby('date')['account_id'].count().reset_index(name='3000').sort_values('date')

# %%
account_cnt_5000 = daily_gcoin_pd[daily_gcoin_pd.gcoin_daily_use >= 5500].groupby('date')['account_id'].count().reset_index(name='5000').sort_values('date')

# %%
a = pd.merge(account_cnt_500, account_cnt_3000, on='date')
a = pd.merge(a, account_cnt_5000, on='date')
a.head()
# Out:
#          date  500  3000  5000
# 0  2021-09-11  601    47   102
# 1  2021-09-12  649    31   109
# 2  2021-09-13  491    29    62
# 3  2021-09-14  421    35    49
# 4  2021-09-15  458    30    93

# %%
a['emote'] = a['500'] * 4.99
a['bundle'] = a['3000'] * 31.99
a['mega'] = a['5000'] * 59.99

# %%
a.head()
# Out:
#          date  500  3000  5000    emote   bundle     mega
# 0  2021-09-11  601    47   102  2998.99  1503.53  6118.98
# 1  2021-09-12  649    31   109  3238.51   991.69  6538.91
# 2  2021-09-13  491    29    62  2450.09   927.71  3719.38
# 3  2021-09-14  421    35    49  2100.79  1119.65  2939.51
# 4  2021-09-15  458    30    93  2285.42   959.70  5579.07

# %%
a.to_csv('console_predicted_min.csv', index=False)

# %%
a[['emote', 'bundle', 'mega']].sum()
# Out:
# emote     201446.30
# bundle    119706.58
# mega      357660.38
# dtype: float64

# %%
a[['emote', 'bundle', 'mega']].sum().values.sum()
# Out:
# 678813.26

# %%
account_cnt_1 = daily_gcoin_pd[(daily_gcoin_pd.gcoin_daily_use >= 500) & (daily_gcoin_pd.gcoin_daily_use < 3000)].groupby('date')['account_id'].count().reset_index(name='500').sort_values('date')
account_cnt_2 = daily_gcoin_pd[(daily_gcoin_pd.gcoin_daily_use >= 3000) & (daily_gcoin_pd.gcoin_daily_use < 5000)].groupby('date')['account_id'].count().reset_index(name='3000').sort_values('date')
account_cnt_3 = daily_gcoin_pd[daily_gcoin_pd.gcoin_daily_use >= 5000].groupby('date')['account_id'].count().reset_index(name='5000').sort_values('date')

# %%
b = pd.merge(account_cnt_1, account_cnt_2, on='date')
b = pd.merge(b, account_cnt_3, on='date')
b.head()
# Out:
#          date   500  3000  5000
# 0  2021-09-11  1271   102   121
# 1  2021-09-12  1441    97   130
# 2  2021-09-13  1024    62    74
# 3  2021-09-14   915    66    62
# 4  2021-09-15   994    72   104

# %%
b['emote'] = b['500'] * 4.99
b['bundle'] = b['3000'] * 31.99
b['mega'] = b['5000'] * 59.99

# %%
b.to_csv('console_predicted_max.csv', index=False)

# %%
b[['emote', 'bundle', 'mega']].sum()
# Out:
# emote     383551.36
# bundle    246898.82
# mega      437867.01
# dtype: float64

# %%
b[['emote', 'bundle', 'mega']].sum().values.sum()
# Out:
# 1068317.1900000002

# %%
19274896.59
# Out:
# 19274896.59

# %%
bundle_prop = gcoin.groupBy('date').agg(countDistinct('transaction_id').alias('trans_cnt'),
                                        count(when(col('product_name').like('%BUNDLE%'), True)).alias('bundle_trans_cnt'),
                                        countDistinct('account_id').alias('account_cnt'),
                                        countDistinct(when(col('product_name').like('%BUNDLE%'), col('account_id'))).alias('bundle_account_cnt'),
                                        sum('price').alias('sum_price'),
                                        sum(when(col('product_name').like('%BUNDLE%'), col('price'))).alias('bundle_sum_price')
                                            ) \
                                              .withColumn('bundle_prop', round(col('bundle_trans_cnt') / col('trans_cnt'), 3)) \
                                              .withColumn('bundle_account_prop', round(col('bundle_account_cnt') / col('account_cnt'), 3)).orderBy('date') \
                                              .withColumn('bundle_price_prop', round(col('bundle_sum_price') / col('sum_price'), 3))

# %%
bundle_prop_pd = bundle_prop.toPandas()

# %%
bundle_prop_pd
# Out:
#           date  trans_cnt  bundle_trans_cnt  account_cnt  bundle_account_cnt  \
# 0   2021-09-11       4781               228         2001                 200
# 1   2021-09-12       5296               245         2187                 220
# 2   2021-09-13       3642               160         1625                 138
# 3   2021-09-14       3279               147         1457                 127
# 4   2021-09-15       3994               201         1566                 152
# 5   2021-09-16      17968               574         9503                 559
# 6   2021-09-17      16372              1477         8646                1360
# 7   2021-09-18      16488              1283         7617                1178
# 8   2021-09-19      11990               856         5897                 795
# 9   2021-09-20       8109               557         3997                 506
# 10  2021-09-21       6830               458         3385                 424
# 11  2021-09-22       6445               376         3033                 343
# 12  2021-09-23       5814               368         2886                 342
# 13  2021-09-24       5897               353         2727                 322
# 14  2021-09-25       7172               410         3364                 385
# 15  2021-09-26       6775               424         3255                 400
# 16  2021-09-27       5294               295         2400                 267
# 17  2021-09-28       4774               277         2267                 255
# 18  2021-09-29       7408               566         3974                 529
# 19  2021-09-30       6354               495         3314                 460
# 20  2021-10-01       5900               444         2948                 406
# 21  2021-10-02       7003               516         3460                 481
# 22  2021-10-03       6618               474         3331                 430
# 23  2021-10-04       4601               328         2379                 303
# 24  2021-10-05       4518               247         2170                 231
# 25  2021-10-06       3973               223         2009                 205
# 26  2021-10-07       3886               234         1970                 228
# 27  2021-10-08       4355               222         2108                 203
# 28  2021-10-09       5417               303         2485                 280
# 29  2021-10-10       5089               312         2520                 291
# 30  2021-10-11       4122               245         1975                 235
# 31  2021-10-12       3448               184         1666                 168
# 32  2021-10-13       3562               220         1700                 194
# 33  2021-10-14      14283               179         3835                 169
# 34  2021-10-15      12362               260         3797                 241
# 35  2021-10-16      11009               330         3735                 305
# 36  2021-10-17       9235               275         3413                 259
#
#     sum_price  bundle_sum_price  bundle_prop  bundle_account_prop  \
# 0     3284330            627310        0.048                0.100
# 1     3647140            644230        0.046                0.101
# 2     2325170            401630        0.044                0.085
# 3     2005960            317910        0.045                0.087
# 4     2793980            515400        0.050                0.097
# 5    18116390           2069760        0.032                0.059
# 6    15968160           3523900        0.090                0.157
# 7    14124660           2867210        0.078                0.155
# 8     9276490           1772760        0.071                0.135
# 9     6292430           1201420        0.069                0.127
# 10    5225210            985010        0.067                0.125
# 11    4695110            820450        0.058                0.113
# 12    4156800            775610        0.063                0.119
# 13    4166310            770210        0.060                0.118
# 14    5044800            848200        0.057                0.114
# 15    4650440            922550        0.063                0.123
# 16    3587350            630130        0.056                0.111
# 17    3304870            604650        0.058                0.112
# 18    4534550            813360        0.076                0.133
# 19    4058180            794440        0.078                0.139
# 20    3834060            739850        0.075                0.138
# 21    4698350            938180        0.074                0.139
# 22    4129620            861300        0.072                0.129
# 23    2962120            625370        0.071                0.127
# 24    2790440            462740        0.055                0.106
# 25    2523990            423070        0.056                0.102
# 26    2460980            388640        0.060                0.116
# 27    2823730            435530        0.051                0.096
# 28    3422980            552360        0.056                0.113
# 29    3278980            579200        0.061                0.115
# 30    2505270            453930        0.059                0.119
# 31    2227850            367560        0.053                0.101
# 32    2192340            380800        0.062                0.114
# 33   11851660            350580        0.013                0.044
# 34    9671980            543390        0.021                0.063
# 35    8234910            664810        0.030                0.082
# 36    6486200            521890        0.030                0.076
#
#     bundle_price_prop
# 0               0.191
# 1               0.177
# 2               0.173
# 3               0.158
# 4               0.184
# 5               0.114
# 6               0.221
# 7               0.203
# 8               0.191
# 9               0.191
# 10              0.189
# 11              0.175
# 12              0.187
# 13              0.185
# 14              0.168
# 15              0.198
# 16              0.176
# 17              0.183
# 18              0.179
# 19              0.196
# 20              0.193
# 21              0.200
# 22              0.209
# 23              0.211
# 24              0.166
# 25              0.168
# 26              0.158
# 27              0.154
# 28              0.161
# 29              0.177
# 30              0.181
# 31              0.165
# 32              0.174
# 33              0.030
# 34              0.056
# 35              0.081
# 36              0.080

# %%
bundle_prop_pd.to_csv('bundle_prop_pd.csv', index=False)

# %% [markdown]
# ## GCOIN_USE PC

# %%
gcoin_pc = load_data_mart(start_date=start_date, end_date=end_date, device='pc', table_name='gcoin_use')
bundle_prop_pc = gcoin_pc.groupBy('date').agg(countDistinct('transaction_id').alias('trans_cnt'),
                                        count(when(col('product_name').like('%BUNDLE%'), True)).alias('bundle_trans_cnt'),
                                        countDistinct('account_id').alias('account_cnt'),
                                        countDistinct(when(col('product_name').like('%BUNDLE%'), col('account_id'))).alias('bundle_account_cnt'),
                                        sum('price').alias('sum_price'),
                                        sum(when(col('product_name').like('%BUNDLE%'), col('price'))).alias('bundle_sum_price')
                                            ) \
                                              .withColumn('bundle_prop', round(col('bundle_trans_cnt') / col('trans_cnt'), 3)) \
                                              .withColumn('bundle_account_prop', round(col('bundle_account_cnt') / col('account_cnt'), 3)).orderBy('date') \
                                              .withColumn('bundle_price_prop', round(col('bundle_sum_price') / col('sum_price'), 3))

# %%
bundle_prop_pc_pd = bundle_prop_pc.toPandas()

# %%
bundle_prop_pc_pd.to_csv('bundle_prop_pc_pd.csv', index=False)

# %%
bundle_prop_pc_pd
# Out:
#           date  trans_cnt  bundle_trans_cnt  account_cnt  bundle_account_cnt  \
# 0   2021-09-11     152318              4372        57807                3990
# 1   2021-09-12     116823              3541        47211                3265
# 2   2021-09-13      91987              2722        35031                2491
# 3   2021-09-14      81547              2393        31086                2171
# 4   2021-09-15      90530              2367        33523                2191
# 5   2021-09-16      85116              2319        32263                2131
# 6   2021-09-17     178584             37363        80685               35438
# 7   2021-09-18     130769             19062        56726               17935
# 8   2021-09-19     114381             13262        48977               12431
# 9   2021-09-20     102357             10251        42711                9626
# 10  2021-09-21      95313              8588        39139                8079
# 11  2021-09-22      83981              7116        34318                6619
# 12  2021-09-23      69857              5448        29134                5110
# 13  2021-09-24      72064              5090        29242                4743
# 14  2021-09-25      76851              5344        31515                4946
# 15  2021-09-26      66752              4271        27107                3964
# 16  2021-09-27      60139              3840        24191                3489
# 17  2021-09-28      75336              3790        34449                3453
# 18  2021-09-29     218197             15065       113063               13963
# 19  2021-09-30     142793              8807        80119                8140
# 20  2021-10-01     140913              7767        83982                7216
# 21  2021-10-02     139684              6636        88829                6171
# 22  2021-10-03     144846              6156        97615                5721
# 23  2021-10-04     144135              5628        99355                5243
# 24  2021-10-05     147071              5297       104531                4955
# 25  2021-10-06     434743              4676       141869                4432
# 26  2021-10-07     346121              5695       146433                5367
# 27  2021-10-08     260436              5334       119864                5069
# 28  2021-10-09     307789              7748       167767                7416
# 29  2021-10-10     322317              9284       185605                8914
# 30  2021-10-11     134604              3919        57936                3700
# 31  2021-10-12      98300              3066        40890                2861
# 32  2021-10-13      99798              2913        40011                2716
# 33  2021-10-14      91410              2971        36662                2763
# 34  2021-10-15     100210              3778        37444                3515
# 35  2021-10-16     101209              3644        39170                3383
# 36  2021-10-17      85643              3308        34835                3104
#
#     sum_price  bundle_sum_price  bundle_prop  bundle_account_prop  \
# 0   150629860          15518660        0.029                0.069
# 1   109972260          11959970        0.030                0.069
# 2    86833530           8810450        0.030                0.071
# 3    76685590           7723980        0.029                0.070
# 4    81993200           8180770        0.026                0.065
# 5    76695590           7976670        0.027                0.066
# 6   236702050         112402470        0.209                0.439
# 7   146771550          51924650        0.146                0.316
# 8   118942230          35212680        0.116                0.254
# 9   102398620          26969320        0.100                0.225
# 10   93765690          22103630        0.090                0.206
# 11   80613660          18697880        0.085                0.193
# 12   65452770          13867300        0.078                0.175
# 13   67329910          13217340        0.071                0.162
# 14   72011040          13783020        0.070                0.157
# 15   60831170          11100180        0.064                0.146
# 16   57901850          10476640        0.064                0.144
# 17   65194640          10531000        0.050                0.100
# 18  137940540          21639880        0.069                0.123
# 19   89257920          14921230        0.062                0.102
# 20   82867020          14004520        0.055                0.086
# 21   77879120          12486820        0.048                0.069
# 22   76804540          11777420        0.043                0.059
# 23   74195050          10509230        0.039                0.053
# 24   73323380           9894820        0.036                0.047
# 25  407601440           8327570        0.011                0.031
# 26  278781290          10078080        0.016                0.037
# 27  194522980           9492510        0.020                0.042
# 28  196183330          12735440        0.025                0.044
# 29  193197790          15316250        0.029                0.048
# 30  104285580           7676730        0.029                0.064
# 31   77864460           6191640        0.031                0.070
# 32   78578170           5865580        0.029                0.068
# 33   72926170           5810520        0.033                0.075
# 34   83755930           7242370        0.038                0.094
# 35   83111930           7472330        0.036                0.086
# 36   69013010           6769580        0.039                0.089
#
#     bundle_price_prop
# 0               0.103
# 1               0.109
# 2               0.101
# 3               0.101
# 4               0.100
# 5               0.104
# 6               0.475
# 7               0.354
# 8               0.296
# 9               0.263
# 10              0.236
# 11              0.232
# 12              0.212
# 13              0.196
# 14              0.191
# 15              0.182
# 16              0.181
# 17              0.162
# 18              0.157
# 19              0.167
# 20              0.169
# 21              0.160
# 22              0.153
# 23              0.142
# 24              0.135
# 25              0.020
# 26              0.036
# 27              0.049
# 28              0.065
# 29              0.079
# 30              0.074
# 31              0.080
# 32              0.075
# 33              0.080
# 34              0.086
# 35              0.090
# 36              0.098
