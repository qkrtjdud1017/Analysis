# %%
from pubg_util import mysql, load_schema, notifier
from sphynx import sphynx, NODE_SMALL, NODE_MEDIUM, NODE_LARGE
from pyspark.sql.functions import *

spark = sphynx.get_spark(executor_count=4, app_name='pdu_syp', node_spec=NODE_MEDIUM)
# Out:
# Spark cluster not assigned. creating a new one...
# Node spec: 4 executors with 24G RAM each
# Job Port 4049 is assigned for requested cluster
# Waiting for Spark master to be available...
# Spark master launched!
# Creating new Spark session, name: pdu_syp...
# Waiting for all executors ready...
# All executors connected!
# Complete! elapsed time: 00:00:26

# %%
sphynx.stop()

# %% [markdown]
# #### PGC 2021
# - 2021-11-12 ~ 2021-12-18 (37일)
# - 분석 기간: 2021-09-11 ~ 2021-10-17 (37일)

# %%
start_date = '2021-09-11'
end_date = '2021-10-17'

# %% [markdown]
# ### PC

# %%
user_pc = load_data_mart(start_date=start_date, end_date=end_date, device='pc', table_name='user_master')
gcoin_pc = load_data_mart(start_date=start_date, end_date=end_date, device='pc', table_name='gcoin_use')

# %%
gcoin_pc.select('price', 'price_').show(10)
# Out:
# +-----+-------+
# |price| price_|
# +-----+-------+
# |  200| 200.00|
# |  510|1290.00|
# | 1800|1800.00|
# | 1800|1800.00|
# |  400| 400.00|
# |  990| 990.00|
# |  100| 100.00|
# | 1800|1800.00|
# | 1800|1800.00|
# |  500| 500.00|
# +-----+-------+
# only showing top 10 rows

# %% [markdown]
# 주어진 27일 데이터간 au, pu, revenue

# %%
user_pc.where("lastlogindate >= '2021-09-11' ").select('accountid').distinct().count()
# Out:
# 7146056

# %%
gcoin_pc.select(countDistinct('account_id'), sum('price')).show()
# Out:
# +--------------------------+----------+
# |count(DISTINCT account_id)|sum(price)|
# +--------------------------+----------+
# |                   1088092|4202814860|
# +--------------------------+----------+

# %%
gcoin_pc.count()
# Out:
# 5204924

# %%
product_price = gcoin_pc.groupBy('product_name', 'price').agg(countDistinct('account_id'), count("*"), sum('price')).toPandas()

# %%
product_price.shape
# Out:
# (681, 5)

# %%
product_price.sort_values('price', ascending=False).head(10)
# Out:
#                                        product_name  price  \
# 183                           BLACKPINK MEGA BUNDLE   9900
# 236                     SPACE BUNNY ULTIMATE BUNDLE   5440
# 640                            PCS5 ULTIMATE BUNDLE   3960
# 159  SURVIVOR PASS: CRAZY NIGHT WEAPON & LEVEL PACK   3270
# 575                       JENNIE'S BLACKPINK BUNDLE   2780
# 371                         LISA'S BLACKPINK BUNDLE   2780
# 383                        JISOO'S BLACKPINK BUNDLE   2780
# 395                         ROSÉ'S BLACKPINK BUNDLE   2780
# 420                      FLOWER POWER WEAPON BUNDLE   2770
# 553                   SON HEUNG-MIN'S OUTFIT BUNDLE   2530
#
#      count(DISTINCT account_id)  count(1)  sum(price)
# 183                        5235      5235    51826500
# 236                       33357     33357   181462080
# 640                       10706     10706    42395760
# 159                       18060     18060    59056200
# 575                       10265     10265    28536700
# 371                        4454      4454    12382120
# 383                        8519      8519    23682820
# 395                        8766      8766    24369480
# 420                         125       125      346250
# 553                        1368      1368     3461040

# %% [markdown]
# - mega bundle 혹은 bundle 같은 경우 한사람당 한번씩만 구매

# %%
gcoin_pc.where(col('product_name').like("%BUNDLE%")).withColumn("over3000", when(col("price") >= 3000, 1).otherwise(0)).select(countDistinct("account_id"), sum("over3000")).show()
# Out:
# +--------------------------+-------------+
# |count(DISTINCT account_id)|sum(over3000)|
# +--------------------------+-------------+
# |                    213898|        49298|
# +--------------------------+-------------+

# %%
bundle_product_price = gcoin_pc.where(col('product_name').like('%BUNDLE%')).groupBy('product_name', 'price').agg(countDistinct('account_id'), count("*"), sum("price")).toPandas()

# %%
bundle_product_price.shape
# Out:
# (112, 5)

# %%
bundle_product_price.sort_values('price', ascending=False).head()
# Out:
#                     product_name  price  count(DISTINCT account_id)  count(1)  \
# 30         BLACKPINK MEGA BUNDLE   9900                        5235      5235
# 40   SPACE BUNNY ULTIMATE BUNDLE   5440                       33357     33357
# 108         PCS5 ULTIMATE BUNDLE   3960                       10706     10706
# 57       LISA'S BLACKPINK BUNDLE   2780                        4454      4454
# 58      JISOO'S BLACKPINK BUNDLE   2780                        8519      8519
#
#      sum(price)
# 30     51826500
# 40    181462080
# 108    42395760
# 57     12382120
# 58     23682820

# %%
bundle_product_price.sum()
# Out:
# product_name                  FESTIVE FLANNEL WEAPON BUNDLEFAIRIED AWAY BUND...
# price                                                                    157530
# count(DISTINCT account_id)                                               252829
# count(1)                                                                 252831
# sum(price)                                                            598669130
# dtype: object

# %%
bundle_product_price[bundle_product_price.price >= 3000].sum()
# Out:
# product_name                  BLACKPINK MEGA BUNDLESPACE BUNNY ULTIMATE BUND...
# price                                                                     19300
# count(DISTINCT account_id)                                                49298
# count(1)                                                                  49298
# sum(price)                                                            275684340
# dtype: object

# %%
product_price.sum()
# Out:
# product_name                  Animal House - AKMStriped Graffiti Pink - Helm...
# price                                                                    520450
# count(DISTINCT account_id)                                              3048552
# count(1)                                                                5204924
# sum(price)                                                           4202814860
# dtype: object

# %%
gcoin_pc.groupBy('account_id').agg(count("*"), countDistinct(when(col('product_name').like('%BUNDLE%')), col('transaction_id'))).show(10)

# %%
pay_time_per_user = gcoin_pc.groupBy('account_id').agg(count("*"), countDistinct(when(col('product_name').like('%BUNDLE%')), col('transaction_id'))).toPandas()

# %%
gcoin_pc_daily_use = gcoin_pc.groupBy('date', 'account_id').agg(sum('price').alias('gcoin_daily_use'), 
                                                                min('price').alias('min_gcoin'), 
                                                                avg('price').alias('avg_gcoin'), 
                                                                max('price').alias('max_gcoin'),
                                                                countDistinct('transaction_id').alias('trans_time'))

# %%
gcoin_pc_daily_use.count()
# Out:
# 2431095

# %%
gcoin_pc_daily_use_pd = gcoin_pc_daily_use.toPandas()

# %%
gcoin_pc_daily_use_pd.head()
# Out:
#          date                                account_id  gcoin_daily_use  \
# 0  2021-10-08  account.466510fdb1724e50a19ecd7d8f116f00             3090
# 1  2021-09-26  account.1b96ad0279ac4cbb9401dd170b099739             1590
# 2  2021-09-19  account.3946b2a66021440e908d6493dd319e60            15200
# 3  2021-09-21  account.1e76199e59d34bb28c8625440d62bc60             1100
# 4  2021-09-11  account.5813bdd50a6647a58f4d7607059bccbb             1190
#
#    min_gcoin    avg_gcoin  max_gcoin  trans_time
# 0        200   441.428571       1590           7
# 1       1590  1590.000000       1590           1
# 2        200  1266.666667       1800          12
# 3        200   275.000000        500           4
# 4        200   595.000000        990           2

# %% [markdown]
# 한 유저당 하루에 사용하는 gcoin의 정도

# %%
gcoin_pc_daily_use_pd.describe().round(2)
# Out:
#        gcoin_daily_use   min_gcoin   avg_gcoin   max_gcoin  trans_time
# count       2431095.00  2431095.00  2431095.00  2431095.00  2431095.00
# mean           1728.77      534.91      643.04      786.31        2.14
# std            5871.10      684.33      728.93      961.86        4.09
# min             100.00      100.00      100.00      100.00        1.00
# 25%             200.00      200.00      200.00      200.00        1.00
# 50%             500.00      250.00      390.00      480.00        1.00
# 75%            1190.00      590.00      910.00      990.00        2.00
# max          280800.00     9900.00     9900.00     9900.00      365.00

# %%
gcoin_pc_daily_use.columns
# Out:
# ['date',
#  'account_id',
#  'gcoin_daily_use',
#  'min_gcoin',
#  'avg_gcoin',
#  'max_gcoin',
#  'trans_time']

# %%
gcoin_pc_daily_use.printSchema()
# Out:
# root
#  |-- date: string (nullable = true)
#  |-- account_id: string (nullable = true)
#  |-- gcoin_daily_use: long (nullable = true)
#  |-- min_gcoin: long (nullable = true)
#  |-- avg_gcoin: double (nullable = true)
#  |-- max_gcoin: long (nullable = true)
#  |-- trans_time: long (nullable = false)

# %% [markdown]
# 하루 500 ~ 1000 코인 소비하는 유저들

# %%
gcoin_pc_daily_use_pd[(gcoin_pc_daily_use_pd.gcoin_daily_use >= 500) & (gcoin_pc_daily_use_pd.gcoin_daily_use <=1000)].describe()
# Out:
#        gcoin_daily_use      min_gcoin      avg_gcoin      max_gcoin  \
# count    657750.000000  657750.000000  657750.000000  657750.000000
# mean        756.467168     617.220084     632.652367     649.654534
# std         203.726916     295.462984     277.669412     265.456107
# min         500.000000     100.000000     100.000000     100.000000
# 25%         590.000000     490.000000     500.000000     500.000000
# 50%         710.000000     590.000000     590.000000     590.000000
# 75%         990.000000     990.000000     990.000000     990.000000
# max        1000.000000    1000.000000    1000.000000    1000.000000
#
#           trans_time
# count  657750.000000
# mean        1.475719
# std         0.936973
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         9.000000

# %%
x = gcoin_pc_daily_use_pd.groupby('date')['account_id'].count().reset_index(name='account_cnt').sort_values('date')
y = gcoin_pc_daily_use_pd[(gcoin_pc_daily_use_pd.gcoin_daily_use >= 500) & (gcoin_pc_daily_use_pd.gcoin_daily_use <=1000)].groupby('date')['account_id'].count().reset_index(name='account_cnt_').sort_values('date')
z = pd.merge(x, y, on='date')
z['p'] = z['account_cnt_']/z.account_cnt
z
# Out:
#           date  account_cnt  account_cnt_         p
# 0   2021-09-11        57807         23433  0.405366
# 1   2021-09-12        47211         18929  0.400945
# 2   2021-09-13        35031         13449  0.383917
# 3   2021-09-14        31086         11707  0.376600
# 4   2021-09-15        33523         11731  0.349939
# 5   2021-09-16        32263         11593  0.359328
# 6   2021-09-17        80685         19291  0.239090
# 7   2021-09-18        56726         17159  0.302489
# 8   2021-09-19        48977         15885  0.324336
# 9   2021-09-20        42711         14220  0.332935
# 10  2021-09-21        39139         13198  0.337208
# 11  2021-09-22        34318         10886  0.317210
# 12  2021-09-23        29134          9847  0.337990
# 13  2021-09-24        29242          9996  0.341837
# 14  2021-09-25        31515         11170  0.354434
# 15  2021-09-26        27107          9620  0.354890
# 16  2021-09-27        24191          8513  0.351908
# 17  2021-09-28        34449         10237  0.297164
# 18  2021-09-29       113063         32506  0.287503
# 19  2021-09-30        80119         19959  0.249117
# 20  2021-10-01        83982         17939  0.213605
# 21  2021-10-02        88829         17602  0.198156
# 22  2021-10-03        97615         18635  0.190903
# 23  2021-10-04        99355         20760  0.208948
# 24  2021-10-05       104531         24339  0.232840
# 25  2021-10-06       141869         28811  0.203082
# 26  2021-10-07       146433         31257  0.213456
# 27  2021-10-08       119864         27145  0.226465
# 28  2021-10-09       167767         42905  0.255742
# 29  2021-10-10       185605         51664  0.278355
# 30  2021-10-11        57936         16220  0.279964
# 31  2021-10-12        40890         11614  0.284030
# 32  2021-10-13        40011         11161  0.278948
# 33  2021-10-14        36662         10674  0.291146
# 34  2021-10-15        37444         10979  0.293211
# 35  2021-10-16        39170         11865  0.302910
# 36  2021-10-17        34835         10851  0.311497

# %%
z.round(2).to_csv('500_1000.csv', index=False)

# %% [markdown]
# 500~1000 gcoin 상품 구매

# %%
a = gcoin_pc.where('price >= 500 and price <= 1000').groupBy('date').agg(countDistinct('account_id').alias('500_1000'))
b = gcoin_pc.groupBy('date').agg(countDistinct('account_id').alias('cnt'))
c = a.join(b, 'date').withColumn('p', col('500_1000')/col('cnt'))
c
# Out:
# DataFrame[date: string, 500_1000: bigint, cnt: bigint, p: double]

# %%
c.orderBy('date').show()
# Out:
# +----------+--------+------+-------------------+
# |      date|500_1000|   cnt|                  p|
# +----------+--------+------+-------------------+
# |2021-09-11|   33279| 57807| 0.5756915252478073|
# |2021-09-12|   26337| 47211| 0.5578572790239563|
# |2021-09-13|   18596| 35031| 0.5308441095030116|
# |2021-09-14|   15936| 31086| 0.5126423470372515|
# |2021-09-15|   16031| 33523| 0.4782089908421084|
# |2021-09-16|   15889| 32263|0.49248365000154976|
# |2021-09-17|   42901| 80685|  0.531709735390717|
# |2021-09-18|   30671| 56726| 0.5406868102809999|
# |2021-09-19|   26137| 48977| 0.5336586561038855|
# |2021-09-20|   22748| 42711| 0.5326028423591113|
# |2021-09-21|   20592| 39139| 0.5261248371189862|
# |2021-09-22|   16836| 34318| 0.4905880296054549|
# |2021-09-23|   14720| 29134| 0.5052515960733164|
# |2021-09-24|   14859| 29242| 0.5081389781820669|
# |2021-09-25|   16225| 31515| 0.5148342059336823|
# |2021-09-26|   13943| 27107| 0.5143689821817243|
# |2021-09-27|   12307| 24191| 0.5087429209210037|
# |2021-09-28|   14575| 34449| 0.4230892043310401|
# |2021-09-29|   44861|113063|  0.396778787047929|
# |2021-09-30|   26803| 80119| 0.3345398719404885|
# +----------+--------+------+-------------------+
# only showing top 20 rows

# %%
c.orderBy('date').toPandas().round(3).to_csv('small_purchase.csv', index=False)

# %% [markdown]
# 하루에 5000 지코인 이상 소비하는 유저들

# %%
a = gcoin_pc_daily_use_pd.groupby('date')['account_id'].count().reset_index(name='account_cnt').sort_values('date')
b = gcoin_pc_daily_use_pd[gcoin_pc_daily_use_pd.gcoin_daily_use >= 5000].groupby('date')['account_id'].count().reset_index(name='account_cnt_5000').sort_values('date')
c = pd.merge(a, b, on='date')
c['p'] = c.account_cnt_5000/c.account_cnt
c
# Out:
#           date  account_cnt  account_cnt_5000         p
# 0   2021-09-11        57807              6199  0.107236
# 1   2021-09-12        47211              4421  0.093643
# 2   2021-09-13        35031              3486  0.099512
# 3   2021-09-14        31086              3056  0.098308
# 4   2021-09-15        33523              3448  0.102855
# 5   2021-09-16        32263              3161  0.097976
# 6   2021-09-17        80685             16994  0.210622
# 7   2021-09-18        56726              8269  0.145771
# 8   2021-09-19        48977              5989  0.122282
# 9   2021-09-20        42711              4951  0.115919
# 10  2021-09-21        39139              4244  0.108434
# 11  2021-09-22        34318              3773  0.109942
# 12  2021-09-23        29134              2926  0.100432
# 13  2021-09-24        29242              2870  0.098147
# 14  2021-09-25        31515              2960  0.093924
# 15  2021-09-26        27107              2577  0.095068
# 16  2021-09-27        24191              2495  0.103138
# 17  2021-09-28        34449              2638  0.076577
# 18  2021-09-29       113063              3583  0.031690
# 19  2021-09-30        80119              2678  0.033425
# 20  2021-10-01        83982              2595  0.030899
# 21  2021-10-02        88829              2263  0.025476
# 22  2021-10-03        97615              2107  0.021585
# 23  2021-10-04        99355              1906  0.019184
# 24  2021-10-05       104531              1791  0.017134
# 25  2021-10-06       141869             14162  0.099824
# 26  2021-10-07       146433              9992  0.068236
# 27  2021-10-08       119864              6938  0.057882
# 28  2021-10-09       167767              6158  0.036706
# 29  2021-10-10       185605              5418  0.029191
# 30  2021-10-11        57936              3857  0.066573
# 31  2021-10-12        40890              3025  0.073979
# 32  2021-10-13        40011              3097  0.077404
# 33  2021-10-14        36662              2869  0.078255
# 34  2021-10-15        37444              3381  0.090295
# 35  2021-10-16        39170              3294  0.084095
# 36  2021-10-17        34835              2764  0.079345

# %%
c.to_csv('pay_5000.csv', index=False)

# %% [markdown]
# 5000 이상 되는 상품 구매

# %%
a = gcoin_pc.where('price >= 5000').groupBy('date').agg(countDistinct('account_id').alias('5000'))
b = gcoin_pc.groupBy('date').agg(countDistinct('account_id').alias('cnt'))
c = a.join(b, 'date').withColumn('p', col('5000')/col('cnt'))

# %%
c.orderBy('date').show()
# Out:
# +----------+-----+------+--------------------+
# |      date| 5000|   cnt|                   p|
# +----------+-----+------+--------------------+
# |2021-09-11|  365| 57807|0.006314114207621...|
# |2021-09-12|  244| 47211|0.005168287051746415|
# |2021-09-13|  191| 35031|0.005452313665039537|
# |2021-09-14|  169| 31086|0.005436530914237921|
# |2021-09-15|  200| 33523|0.005966053157533...|
# |2021-09-16|  206| 32263|0.006385023091467006|
# |2021-09-17|12909| 80685| 0.15999256367354528|
# |2021-09-18| 4745| 56726| 0.08364771004477664|
# |2021-09-19| 2888| 48977|  0.0589664536415052|
# |2021-09-20| 2079| 42711| 0.04867598510922245|
# |2021-09-21| 1528| 39139| 0.03904034339150208|
# |2021-09-22| 1312| 34318| 0.03823066612273442|
# |2021-09-23|  889| 29134| 0.03051417587698222|
# |2021-09-24|  820| 29242|0.028041857602079202|
# |2021-09-25|  778| 31515|0.024686657147390132|
# |2021-09-26|  603| 27107| 0.02224517652266942|
# |2021-09-27|  591| 24191|0.024430573353726594|
# |2021-09-28|  570| 34449|0.016546198728555256|
# |2021-09-29|  553|113063|0.004891078425302707|
# |2021-09-30|  558| 80119|0.006964640097854442|
# +----------+-----+------+--------------------+
# only showing top 20 rows

# %%
c.orderBy('date').toPandas().round(5).to_csv('5000.csv', index=False)

# %% [markdown]
# BUNDLE 구매 정도

# %%
gcoin_pc.where("lower(product_name) like '%bundle%' ").select('product_name', 'price').distinct().orderBy("price", ascending=False).show(truncate=False)
# Out:
# +-----------------------------------------+-----+
# |product_name                             |price|
# +-----------------------------------------+-----+
# |BLACKPINK MEGA BUNDLE                    |9900 |
# |SPACE BUNNY ULTIMATE BUNDLE              |5440 |
# |PCS5 ULTIMATE BUNDLE                     |3960 |
# |JISOO'S BLACKPINK BUNDLE                 |2780 |
# |JENNIE'S BLACKPINK BUNDLE                |2780 |
# |ROSÉ'S BLACKPINK BUNDLE                  |2780 |
# |LISA'S BLACKPINK BUNDLE                  |2780 |
# |FLOWER POWER WEAPON BUNDLE               |2770 |
# |SON HEUNG-MIN'S OUTFIT BUNDLE            |2530 |
# |MOO'D KILLER WEAPON BUNDLE               |2420 |
# |FLOWER POWER WEAPON BUNDLE               |2370 |
# |MOO'D KILLER WEAPON BUNDLE               |2080 |
# |LAUGHING STOCKS BUNDLE                   |2070 |
# |COLORFUL CHAOS WEAPON BUNDLE 1           |2070 |
# |COLORFUL CHAOS WEAPON BUNDLE 1           |2000 |
# |COLORFUL CHAOS WEAPON BUNDLE 2           |2000 |
# |MANTICORE YELLOW MOTOCROSS AND AKM BUNDLE|1980 |
# |MANTICORE BLACK MOTOCROSS AND SLR BUNDLE |1980 |
# |FLOWER POWER WEAPON BUNDLE               |1980 |
# |ENDURO STUNT SUIT AND UMP BUNDLE         |1790 |
# +-----------------------------------------+-----+
# only showing top 20 rows

# %%
bundle = gcoin_pc.where("product_name like '%BUNDLE%' ").groupBy('date').agg(countDistinct('account_id').alias('account_cnt'), 
                                                                             countDistinct('transaction_id').alias('trans_cnt'),
                                                                             countDistinct('product_name').alias('nunique_bundle'),
                                                                             sum('price').alias('sum_price')
                                                                            ).orderBy("date")
bundle_3000 = gcoin_pc.where("product_name like '%BUNDLE%' and price >= 3000").groupBy('date').agg(countDistinct('account_id').alias('3000_account_cnt'), 
                                                                                                   countDistinct('transaction_id').alias('3000_trans_cnt'),
                                                                                                   countDistinct('product_name').alias('3000_nunique_bundle'),
                                                                                                   sum('price').alias('3000_sum_price')
                                                                                                  ).orderBy("date")

# %%
bundle.join(bundle_3000, 'date').withColumn('account percentage', round(col('3000_account_cnt')/col('account_cnt')*100, 2)) \
                                .withColumn('trans percentage', round(col('3000_trans_cnt')/col('trans_cnt')*100, 2)) \
                                .withColumn('price percentage', round(col('3000_sum_price')/col('sum_price')*100, 2)) \
                                .orderBy('date').toPandas().to_csv('bundle.csv', index=False)

# %%
bundle.join(bundle_3000, 'date').withColumn('account percentage', round(col('3000_account_cnt')/col('account_cnt')*100, 2)) \
                                .withColumn('trans percentage', round(col('3000_trans_cnt')/col('trans_cnt')*100, 2)) \
                                .withColumn('price percentage', round(col('3000_sum_price')/col('sum_price')*100, 2)) \
                                .orderBy('date').show(40)
# Out:
# +----------+-----------+---------+--------------+---------+----------------+--------------+-------------------+--------------+------------------+----------------+----------------+
# |      date|account_cnt|trans_cnt|nunique_bundle|sum_price|3000_account_cnt|3000_trans_cnt|3000_nunique_bundle|3000_sum_price|account percentage|trans percentage|price percentage|
# +----------+-----------+---------+--------------+---------+----------------+--------------+-------------------+--------------+------------------+----------------+----------------+
# |2021-09-11|       3990|     4372|            28| 15518660|            2056|          2078|                  2|      10396980|             51.53|           47.53|            67.0|
# |2021-09-12|       3265|     3541|            27| 11959970|            1457|          1473|                  2|       7282440|             44.62|            41.6|           60.89|
# |2021-09-13|       2491|     2722|            28|  8810450|             975|           985|                  2|       5035140|             39.14|           36.19|           57.15|
# |2021-09-14|       2171|     2393|            26|  7723980|             774|           787|                  2|       4120380|             35.65|           32.89|           53.35|
# |2021-09-15|       2191|     2367|            27|  8180770|             897|           909|                  2|       4787640|             40.94|            38.4|           58.52|
# |2021-09-16|       2131|     2319|            27|  7976670|             830|           840|                  2|       4550040|             38.95|           36.22|           57.04|
# |2021-09-17|      35438|    37363|            30|112402470|           13291|         13487|                  3|      73594380|              37.5|            36.1|           65.47|
# |2021-09-18|      17935|    19062|            31| 51924650|            5187|          5347|                  3|      29088540|             28.92|           28.05|           56.02|
# |2021-09-19|      12431|    13262|            31| 35212680|            3251|          3378|                  3|      18446320|             26.15|           25.47|           52.39|
# |2021-09-20|       9626|    10251|            29| 26969320|            2364|          2456|                  3|      13528060|             24.56|           23.96|           50.16|
# |2021-09-21|       8079|     8588|            30| 22103630|            1796|          1855|                  3|      10365340|             22.23|            21.6|           46.89|
# |2021-09-22|       6619|     7116|            30| 18697880|            1523|          1578|                  3|       8908580|             23.01|           22.18|           47.64|
# |2021-09-23|       5110|     5448|            30| 13867300|            1093|          1136|                  3|       6260220|             21.39|           20.85|           45.14|
# |2021-09-24|       4743|     5090|            29| 13217340|            1039|          1084|                  3|       6103780|             21.91|            21.3|           46.18|
# |2021-09-25|       4946|     5344|            30| 13783020|            1062|          1122|                  3|       6230720|             21.47|            21.0|           45.21|
# |2021-09-26|       3964|     4271|            31| 11100180|             839|           897|                  3|       4990020|             21.17|            21.0|           44.95|
# |2021-09-27|       3489|     3840|            30| 10476640|             917|           995|                  3|       5332140|             26.28|           25.91|            50.9|
# |2021-09-28|       3453|     3790|            29| 10531000|             993|          1047|                  3|       5536780|             28.76|           27.63|           52.58|
# |2021-09-29|      13963|    15065|            43| 21639880|             934|           993|                  3|       5302200|              6.69|            6.59|            24.5|
# |2021-09-30|       8140|     8807|            43| 14921230|             690|           708|                  3|       4200320|              8.48|            8.04|           28.15|
# |2021-10-01|       7216|     7767|            42| 14004520|             584|           594|                  2|       3837920|              8.09|            7.65|            27.4|
# |2021-10-02|       6171|     6636|            43| 12486820|             513|           523|                  2|       3460600|              8.31|            7.88|           27.71|
# |2021-10-03|       5721|     6156|            43| 11777420|             487|           499|                  2|       3352340|              8.51|            8.11|           28.46|
# |2021-10-04|       5243|     5628|            43| 10509230|             409|           419|                  2|       2810100|               7.8|            7.44|           26.74|
# |2021-10-05|       4955|     5297|            43|  9894820|             402|           408|                  2|       2745800|              8.11|             7.7|           27.75|
# |2021-10-06|       4432|     4676|            42|  8327570|             307|           316|                  2|       2169500|              6.93|            6.76|           26.05|
# |2021-10-07|       5367|     5695|            43| 10078080|             370|           380|                  2|       2580100|              6.89|            6.67|            25.6|
# |2021-10-08|       5069|     5334|            42|  9492510|             341|           346|                  2|       2292560|              6.73|            6.49|           24.15|
# |2021-10-09|       7416|     7748|            42| 12735440|             359|           370|                  2|       2543540|              4.84|            4.78|           19.97|
# |2021-10-10|       8914|     9284|            41| 15316250|             453|           457|                  2|       3074800|              5.08|            4.92|           20.08|
# |2021-10-11|       3700|     3919|            43|  7676730|             279|           284|                  2|       1955280|              7.54|            7.25|           25.47|
# |2021-10-12|       2861|     3066|            42|  6191640|             226|           233|                  2|       1602020|               7.9|             7.6|           25.87|
# |2021-10-13|       2716|     2913|            43|  5865580|             225|           230|                  2|       1643680|              8.28|             7.9|           28.02|
# |2021-10-14|       2763|     2971|            43|  5810520|             222|           230|                  2|       1576780|              8.03|            7.74|           27.14|
# |2021-10-15|       3515|     3778|            43|  7242370|             264|           269|                  2|       1873680|              7.51|            7.12|           25.87|
# |2021-10-16|       3383|     3644|            41|  7472330|             307|           311|                  2|       2204740|              9.07|            8.53|           29.51|
# |2021-10-17|       3104|     3308|            43|  6769580|             265|           274|                  2|       1900880|              8.54|            8.28|           28.08|
# +----------+-----------+---------+--------------+---------+----------------+--------------+-------------------+--------------+------------------+----------------+----------------+

# %%
bundle_pd = bundle.join(bundle_3000, 'date').withColumn('account percentage', round(col('3000_account_cnt')/col('account_cnt')*100, 2)) \
                                .withColumn('trans percentage', round(col('3000_trans_cnt')/col('trans_cnt')*100, 2)) \
                                .withColumn('price percentage', round(col('3000_sum_price')/col('sum_price')*100, 2)) \
                                .orderBy('date').toPandas()

# %% [markdown]
# - 값 싼 번들의 개수가 더 많아지면서 비교적 저렴한 번들의 구매량이 더 많아짐
# -

# %%
gcoin_pc.where("date == '2021-09-11' and product_name like '%BUNDLE%' ").groupBy('product_name').count().orderBy('product_name').show(30, truncate=False)
# Out:
# +-----------------------------------------+-----+
# |product_name                             |count|
# +-----------------------------------------+-----+
# |BLACKPINK MEGA BUNDLE                    |365  |
# |CIRCUS STAR BUNDLE                       |54   |
# |CNH'S BUNDLE                             |121  |
# |COLORFUL CHAOS WEAPON BUNDLE 1           |5    |
# |COLORFUL CHAOS WEAPON BUNDLE 2           |11   |
# |ENDURO STUNT SUIT AND UMP BUNDLE         |1    |
# |GRAFFITI BACKPACK BUNDLE                 |74   |
# |GRAFFITI HELMET BUNDLE                   |16   |
# |GROOVY GETUP BUNDLE                      |6    |
# |GROOVY OUTFIT BUNDLE                     |11   |
# |HIP OUTFIT BUNDLE                        |3    |
# |JENNIE'S BLACKPINK BUNDLE                |455  |
# |JISOO'S BLACKPINK BUNDLE                 |372  |
# |LISA'S BLACKPINK BUNDLE                  |169  |
# |LONGSKR'S BUNDLE                         |107  |
# |MANTICORE BLACK MOTOCROSS AND SLR BUNDLE |2    |
# |MANTICORE YELLOW MOTOCROSS AND AKM BUNDLE|4    |
# |ONE LOVE OUTFIT BUNDLE                   |8    |
# |PCS5 ULTIMATE BUNDLE                     |1713 |
# |RINGLEADER BUNDLE                        |5    |
# |ROSÉ'S BLACKPINK BUNDLE                  |402  |
# |SKULLFACE STUNT SUIT AND P18C BUNDLE     |11   |
# |SON HEUNG-MIN'S CLOTHING BUNDLE          |17   |
# |SON HEUNG-MIN'S JERSEY BUNDLE            |6    |
# |SON HEUNG-MIN'S OUTFIT BUNDLE            |43   |
# |SON HEUNG-MIN'S WEAPON BUNDLE            |286  |
# |VIGILANTE BACKPACK BUNDLE                |56   |
# |VIGILANTE HELMET BUNDLE                  |49   |
# +-----------------------------------------+-----+

# %%
gcoin_pc.where("date == '2021-10-17' and product_name like '%BUNDLE%' ").groupBy('product_name').count().orderBy('product_name').show(30, truncate=False)
# Out:
# +-----------------------------------------+-----+
# |product_name                             |count|
# +-----------------------------------------+-----+
# |"YEAR OF THE COW" OUTFIT BUNDLE 2        |28   |
# |B.A.S.A. BUNNY BUNDLE                    |487  |
# |BLACKPINK MEGA BUNDLE                    |92   |
# |CIRCUS STAR BUNDLE                       |14   |
# |COLORFUL CHAOS WEAPON BUNDLE 1           |3    |
# |COLORFUL CHAOS WEAPON BUNDLE 2           |6    |
# |ENDURO STUNT SUIT AND UMP BUNDLE         |1    |
# |EVENING BLOOM BUNDLE                     |29   |
# |FAIRIED AWAY BUNDLE                      |27   |
# |FANCY BERYL BUNDLE                       |303  |
# |FESTIVE FLANNEL WEAPON BUNDLE            |83   |
# |FLOWER POWER WEAPON BUNDLE               |43   |
# |GRAFFITI BACKPACK BUNDLE                 |28   |
# |GRAFFITI HELMET BUNDLE                   |2    |
# |GROOVY GETUP BUNDLE                      |1    |
# |GROOVY OUTFIT BUNDLE                     |4    |
# |HIP OUTFIT BUNDLE                        |4    |
# |JENNIE'S BLACKPINK BUNDLE                |193  |
# |JISOO'S BLACKPINK BUNDLE                 |169  |
# |LAUGHING STOCKS BUNDLE                   |89   |
# |LISA'S BLACKPINK BUNDLE                  |109  |
# |LONGSKR'S BUNDLE                         |71   |
# |MANTICORE BLACK MOTOCROSS AND SLR BUNDLE |22   |
# |MANTICORE YELLOW MOTOCROSS AND AKM BUNDLE|1    |
# |MARQUIS DE FOX BUNDLE                    |49   |
# |MOO'D KILLER WEAPON BUNDLE               |41   |
# |MOON RABBIT BUNDLE                       |448  |
# |MOON SEEKER BUNDLE                       |67   |
# |NO STRINGS ATTACHED BUNDLE               |101  |
# |ONE LOVE OUTFIT BUNDLE                   |20   |
# +-----------------------------------------+-----+
# only showing top 30 rows

# %% [markdown]
# MEGA BUNDLE

# %%
gcoin_pc.where('price >= 5000').select('product_name', 'price').distinct().show()
# Out:
# +--------------------+-----+
# |        product_name|price|
# +--------------------+-----+
# |BLACKPINK MEGA BU...| 9900|
# |SPACE BUNNY ULTIM...| 5440|
# +--------------------+-----+

# %%
gcoin_pc.where('price >= 5000').groupBy('date', 'product_name').agg(
    countDistinct('transaction_id'),
    countDistinct('account_id'),
    sum('price')
).orderBy('date', 'product_name').show(100)
# Out:
# +----------+--------------------+------------------------------+--------------------------+----------+
# |      date|        product_name|count(DISTINCT transaction_id)|count(DISTINCT account_id)|sum(price)|
# +----------+--------------------+------------------------------+--------------------------+----------+
# |2021-09-11|BLACKPINK MEGA BU...|                           365|                       365|   3613500|
# |2021-09-12|BLACKPINK MEGA BU...|                           244|                       244|   2415600|
# |2021-09-13|BLACKPINK MEGA BU...|                           191|                       191|   1890900|
# |2021-09-14|BLACKPINK MEGA BU...|                           169|                       169|   1673100|
# |2021-09-15|BLACKPINK MEGA BU...|                           200|                       200|   1980000|
# |2021-09-16|BLACKPINK MEGA BU...|                           206|                       206|   2039400|
# |2021-09-17|BLACKPINK MEGA BU...|                           229|                       229|   2267100|
# |2021-09-17|SPACE BUNNY ULTIM...|                         12720|                     12720|  69196800|
# |2021-09-18|BLACKPINK MEGA BU...|                           191|                       191|   1890900|
# |2021-09-18|SPACE BUNNY ULTIM...|                          4581|                      4581|  24920640|
# |2021-09-19|BLACKPINK MEGA BU...|                           170|                       170|   1683000|
# |2021-09-19|SPACE BUNNY ULTIM...|                          2743|                      2743|  14921920|
# |2021-09-20|BLACKPINK MEGA BU...|                           157|                       157|   1554300|
# |2021-09-20|SPACE BUNNY ULTIM...|                          1939|                      1939|  10548160|
# |2021-09-21|BLACKPINK MEGA BU...|                           165|                       165|   1633500|
# |2021-09-21|SPACE BUNNY ULTIM...|                          1378|                      1378|   7496320|
# |2021-09-22|BLACKPINK MEGA BU...|                           155|                       155|   1534500|
# |2021-09-22|SPACE BUNNY ULTIM...|                          1175|                      1175|   6392000|
# |2021-09-23|BLACKPINK MEGA BU...|                            97|                        97|    960300|
# |2021-09-23|SPACE BUNNY ULTIM...|                           801|                       801|   4357440|
# |2021-09-24|BLACKPINK MEGA BU...|                           129|                       129|   1277100|
# |2021-09-24|SPACE BUNNY ULTIM...|                           706|                       706|   3840640|
# |2021-09-25|BLACKPINK MEGA BU...|                           136|                       136|   1346400|
# |2021-09-25|SPACE BUNNY ULTIM...|                           662|                       662|   3601280|
# |2021-09-26|BLACKPINK MEGA BU...|                           115|                       115|   1138500|
# |2021-09-26|SPACE BUNNY ULTIM...|                           510|                       510|   2774400|
# |2021-09-27|BLACKPINK MEGA BU...|                           111|                       111|   1098900|
# |2021-09-27|SPACE BUNNY ULTIM...|                           495|                       495|   2692800|
# |2021-09-28|BLACKPINK MEGA BU...|                           121|                       121|   1197900|
# |2021-09-28|SPACE BUNNY ULTIM...|                           454|                       454|   2469760|
# |2021-09-29|BLACKPINK MEGA BU...|                           120|                       120|   1188000|
# |2021-09-29|SPACE BUNNY ULTIM...|                           444|                       444|   2415360|
# |2021-09-30|BLACKPINK MEGA BU...|                           124|                       124|   1227600|
# |2021-09-30|SPACE BUNNY ULTIM...|                           446|                       446|   2426240|
# |2021-10-01|BLACKPINK MEGA BU...|                           136|                       136|   1346400|
# |2021-10-01|SPACE BUNNY ULTIM...|                           458|                       458|   2491520|
# |2021-10-02|BLACKPINK MEGA BU...|                           138|                       138|   1366200|
# |2021-10-02|SPACE BUNNY ULTIM...|                           385|                       385|   2094400|
# |2021-10-03|BLACKPINK MEGA BU...|                           143|                       143|   1415700|
# |2021-10-03|SPACE BUNNY ULTIM...|                           356|                       356|   1936640|
# |2021-10-04|BLACKPINK MEGA BU...|                           119|                       119|   1178100|
# |2021-10-04|SPACE BUNNY ULTIM...|                           300|                       300|   1632000|
# |2021-10-05|BLACKPINK MEGA BU...|                           118|                       118|   1168200|
# |2021-10-05|SPACE BUNNY ULTIM...|                           290|                       290|   1577600|
# |2021-10-06|BLACKPINK MEGA BU...|                           101|                       101|    999900|
# |2021-10-06|SPACE BUNNY ULTIM...|                           215|                       215|   1169600|
# |2021-10-07|BLACKPINK MEGA BU...|                           115|                       115|   1138500|
# |2021-10-07|SPACE BUNNY ULTIM...|                           265|                       265|   1441600|
# |2021-10-08|BLACKPINK MEGA BU...|                            92|                        92|    910800|
# |2021-10-08|SPACE BUNNY ULTIM...|                           254|                       254|   1381760|
# |2021-10-09|BLACKPINK MEGA BU...|                           119|                       119|   1178100|
# |2021-10-09|SPACE BUNNY ULTIM...|                           251|                       251|   1365440|
# |2021-10-10|BLACKPINK MEGA BU...|                           132|                       132|   1306800|
# |2021-10-10|SPACE BUNNY ULTIM...|                           325|                       325|   1768000|
# |2021-10-11|BLACKPINK MEGA BU...|                            92|                        92|    910800|
# |2021-10-11|SPACE BUNNY ULTIM...|                           192|                       192|   1044480|
# |2021-10-12|BLACKPINK MEGA BU...|                            75|                        75|    742500|
# |2021-10-12|SPACE BUNNY ULTIM...|                           158|                       158|    859520|
# |2021-10-13|BLACKPINK MEGA BU...|                            88|                        88|    871200|
# |2021-10-13|SPACE BUNNY ULTIM...|                           142|                       142|    772480|
# |2021-10-14|BLACKPINK MEGA BU...|                            73|                        73|    722700|
# |2021-10-14|SPACE BUNNY ULTIM...|                           157|                       157|    854080|
# |2021-10-15|BLACKPINK MEGA BU...|                            92|                        92|    910800|
# |2021-10-15|SPACE BUNNY ULTIM...|                           177|                       177|    962880|
# |2021-10-16|BLACKPINK MEGA BU...|                           115|                       115|   1138500|
# |2021-10-16|SPACE BUNNY ULTIM...|                           196|                       196|   1066240|
# |2021-10-17|BLACKPINK MEGA BU...|                            92|                        92|    910800|
# |2021-10-17|SPACE BUNNY ULTIM...|                           182|                       182|    990080|
# +----------+--------------------+------------------------------+--------------------------+----------+

# %%
gcoin_pc_daily_use_pd[gcoin_pc_daily_use_pd.date == '2021-09-17']['gcoin_daily_use'].hist()

# %%
user_pc = user_pc.withColumn("week", 
                                    when((user_pc.date >= "2021-09-11") & (user_pc.date <= "2021-09-17"), "week1")
                                    .when((user_pc.date >= "2021-09-18") & (user_pc.date <= "2021-09-24"), "week2")
                                    .when((user_pc.date >= "2021-09-25") & (user_pc.date <= "2021-10-01"), "week3")
                                    .when((user_pc.date >= "2021-10-02") & (user_pc.date <= "2021-10-08"), "week4")
                                    .when((user_pc.date >= "2021-10-09") & (user_pc.date <= "2021-10-15"), "week5")
                                    .when((user_pc.date >= "2021-10-16") & (user_pc.date <= "2021-10-17"), "week6"))

# %%
user_pc = user_pc.withColumn("week_start_date", 
                                    when(user_pc.week == "week1", "2021-09-11")
                                    .when(user_pc.week == "week2", "2021-09-18")
                                    .when(user_pc.week == "week3", "2021-09-25")
                                    .when(user_pc.week == "week4", "2021-10-02")
                                    .when(user_pc.week == "week5", "2021-10-09")
                                    .when(user_pc.week == "week6", "2021-10-16"))

# %%
pc_au_daily = user_pc.where('lastlogindate >= date').groupBy('date').agg(countDistinct('accountid').alias('au')).orderBy('date')

# %%
pc_au_weekly = user_pc.where('lastlogindate >= week_start_date').groupBy('week').agg(countDistinct('accountid').alias('au')).orderBy('week')

# %%
pc_au_weekly.show()
# Out:
# +-----+-------+
# | week|     au|
# +-----+-------+
# |week1|3516815|
# |week2|3769736|
# |week3|3547309|
# |week4|3612634|
# |week5|3254344|
# |week6|2003704|
# +-----+-------+

# %%
pc_au_daily.show()
# Out:
# +----------+-------+
# |      date|     au|
# +----------+-------+
# |2021-09-11|1570210|
# |2021-09-12|1587903|
# |2021-09-13|1367678|
# |2021-09-14|1353961|
# |2021-09-15|1309155|
# |2021-09-16|1372456|
# |2021-09-17|1447139|
# |2021-09-18|1547748|
# |2021-09-19|1634790|
# |2021-09-20|1614602|
# |2021-09-21|1584648|
# |2021-09-22|1479949|
# |2021-09-23|1392222|
# |2021-09-24|1466368|
# |2021-09-25|1581151|
# |2021-09-26|1440587|
# |2021-09-27|1264809|
# |2021-09-28|1361965|
# |2021-09-29|1408458|
# |2021-09-30|1474350|
# +----------+-------+
# only showing top 20 rows

# %%
gcoin_pc = gcoin_pc.withColumn("week", 
                                    when((gcoin_pc.date >= "2021-09-11") & (gcoin_pc.date <= "2021-09-17"), "week1")
                                    .when((gcoin_pc.date >= "2021-09-18") & (gcoin_pc.date <= "2021-09-24"), "week2")
                                    .when((gcoin_pc.date >= "2021-09-25") & (gcoin_pc.date <= "2021-10-01"), "week3")
                                    .when((gcoin_pc.date >= "2021-10-02") & (gcoin_pc.date <= "2021-10-08"), "week4")
                                    .when((gcoin_pc.date >= "2021-10-09") & (gcoin_pc.date <= "2021-10-15"), "week5")
                                    .when((gcoin_pc.date >= "2021-10-16") & (gcoin_pc.date <= "2021-10-17"), "week6"))

# %%
gcoin_pc = gcoin_pc.withColumn("week_start_date", 
                                    when(gcoin_pc.week == "week1", "2021-09-11")
                                    .when(gcoin_pc.week == "week2", "2021-09-18")
                                    .when(gcoin_pc.week == "week3", "2021-09-25")
                                    .when(gcoin_pc.week == "week4", "2021-10-02")
                                    .when(gcoin_pc.week == "week5", "2021-10-09")
                                    .when(gcoin_pc.week == "week6", "2021-10-16"))

# %%
pc_gcoin_daily = gcoin_pc.groupBy('date').agg(countDistinct('account_id').alias('pu'), sum('price').alias('price_sum'), sum('free_use').alias('free_sum'), sum('paid_use').alias('paid_sum')).orderBy('date')
pc_gcoin_weekly = gcoin_pc.groupBy('week').agg(countDistinct('account_id').alias('pu'), sum('price').alias('price_sum'), sum('free_use').alias('free_sum'), sum('paid_use').alias('paid_sum')).orderBy('week')

# %%
pc_gcoin_weekly.show()
# Out:
# +-----+------+----------+---------+---------+
# | week|    pu| price_sum| free_sum| paid_sum|
# +-----+------+----------+---------+---------+
# |week1|246487| 819512080|141155929|691743051|
# |week2|227062| 675274430| 99828810|583778830|
# |week3|314815| 566004180|104345780|469295960|
# |week4|552997|1183107800|301285950|890699450|
# |week5|491315| 806791430|224796715|589921655|
# |week6| 71020| 152124940| 26156400|128097710|
# +-----+------+----------+---------+---------+

# %%
pc_gcoin_daily.show()
# Out:
# +----------+------+---------+--------+---------+
# |      date|    pu|price_sum|free_sum| paid_sum|
# +----------+------+---------+--------+---------+
# |2021-09-11| 57807|150629860|28873070|124667770|
# |2021-09-12| 47211|109972260|20820080| 91577430|
# |2021-09-13| 35031| 86833530|15454890| 73133320|
# |2021-09-14| 31086| 76685590|13069929| 65281031|
# |2021-09-15| 33523| 81993200|13806350| 69854420|
# |2021-09-16| 32263| 76695590|12659150| 65581220|
# |2021-09-17| 80685|236702050|36472460|201647860|
# |2021-09-18| 56726|146771550|21961770|126187570|
# |2021-09-19| 48977|118942230|17868050|102419660|
# |2021-09-20| 42711|102398620|15356980| 88414320|
# |2021-09-21| 39139| 93765690|13703330| 81209430|
# |2021-09-22| 34318| 80613660|11793130| 69979980|
# |2021-09-23| 29134| 65452770| 9533510| 56826210|
# |2021-09-24| 29242| 67329910| 9612040| 58741660|
# |2021-09-25| 31515| 72011040|10268360| 62789580|
# |2021-09-26| 27107| 60831170| 8539440| 53271680|
# |2021-09-27| 24191| 57901850| 8310010| 50541820|
# |2021-09-28| 34449| 65194640|10790840| 55360090|
# |2021-09-29|113063|137940540|26607209|112415291|
# |2021-09-30| 80119| 89257920|19168921| 71346599|
# +----------+------+---------+--------+---------+
# only showing top 20 rows

# %%
pc_au_daily_pd = pc_au_daily.toPandas()
pc_au_weekly_pd = pc_au_weekly.toPandas()
pc_gcoin_daily_pd = pc_gcoin_daily.toPandas()
pc_gcoin_weekly_pd = pc_gcoin_weekly.toPandas()

# %%
import pandas as pd

pc_au_daily_pd.date = pc_au_daily_pd.date.astype(str)
pc_gcoin_daily_pd.date = pc_gcoin_daily_pd.date.astype(str)
pur_daily = pd.merge(pc_au_daily_pd, pc_gcoin_daily_pd, on='date')

# %%
pur_daily['pur'] = pur_daily.pu/pur_daily.au
pur_daily['arpu'] = pur_daily.price_sum/pur_daily.au
pur_daily['arppu'] = pur_daily.price_sum/pur_daily.pu

# %%
bundle_pd.head()
# Out:
#          date  account_cnt  trans_cnt  nunique_bundle  sum_price  \
# 0  2021-09-11         3990       4372              28   15518660
# 1  2021-09-12         3265       3541              27   11959970
# 2  2021-09-13         2491       2722              28    8810450
# 3  2021-09-14         2171       2393              26    7723980
# 4  2021-09-15         2191       2367              27    8180770
#
#    3000_account_cnt  3000_trans_cnt  3000_nunique_bundle  3000_sum_price  \
# 0              2056            2078                    2        10396980
# 1              1457            1473                    2         7282440
# 2               975             985                    2         5035140
# 3               774             787                    2         4120380
# 4               897             909                    2         4787640
#
#    account percentage  trans percentage  price percentage
# 0               51.53             47.53             67.00
# 1               44.62             41.60             60.89
# 2               39.14             36.19             57.15
# 3               35.65             32.89             53.35
# 4               40.94             38.40             58.52

# %%
tmp = pur_daily.merge(bundle_pd, on='date')
tmp['bundle/total'] = tmp['sum_price']/tmp['price_sum']
tmp
# Out:
#           date       au      pu  price_sum  free_sum   paid_sum       pur  \
# 0   2021-09-11  1570210   57807  150629860  28873070  124667770  0.036815
# 1   2021-09-12  1587903   47211  109972260  20820080   91577430  0.029732
# 2   2021-09-13  1367678   35031   86833530  15454890   73133320  0.025613
# 3   2021-09-14  1353961   31086   76685590  13069929   65281031  0.022959
# 4   2021-09-15  1309155   33523   81993200  13806350   69854420  0.025607
# 5   2021-09-16  1372456   32263   76695590  12659150   65581220  0.023507
# 6   2021-09-17  1447139   80685  236702050  36472460  201647860  0.055755
# 7   2021-09-18  1547748   56726  146771550  21961770  126187570  0.036651
# 8   2021-09-19  1634790   48977  118942230  17868050  102419660  0.029959
# 9   2021-09-20  1614602   42711  102398620  15356980   88414320  0.026453
# 10  2021-09-21  1584648   39139   93765690  13703330   81209430  0.024699
# 11  2021-09-22  1479949   34318   80613660  11793130   69979980  0.023189
# 12  2021-09-23  1392222   29134   65452770   9533510   56826210  0.020926
# 13  2021-09-24  1466368   29242   67329910   9612040   58741660  0.019942
# 14  2021-09-25  1581151   31515   72011040  10268360   62789580  0.019932
# 15  2021-09-26  1440587   27107   60831170   8539440   53271680  0.018817
# 16  2021-09-27  1264809   24191   57901850   8310010   50541820  0.019126
# 17  2021-09-28  1361965   34449   65194640  10790840   55360090  0.025294
# 18  2021-09-29  1408458  113063  137940540  26607209  112415291  0.080274
# 19  2021-09-30  1474350   80119   89257920  19168921   71346599  0.054342
# 20  2021-10-01  1561068   83982   82867020  20661000   63570900  0.053798
# 21  2021-10-02  1597998   88829   77879120  23004650   56090140  0.055588
# 22  2021-10-03  1625859   97615   76804540  27081850   51058850  0.060039
# 23  2021-10-04  1579853   99355   74195050  29048710   46457120  0.062889
# 24  2021-10-05  1532616  104531   73323380  32186380   42495970  0.068204
# 25  2021-10-06  1317550  141869  407601440  77771950  330871780  0.107676
# 26  2021-10-07  1529520  146433  278781290  64016030  216198850  0.095738
# 27  2021-10-08  1442636  119864  194522980  48176380  147526740  0.083087
# 28  2021-10-09  1570124  167767  196183330  67472790  130231080  0.106850
# 29  2021-10-10  1624656  185605  193197790  75282140  119551120  0.114243
# 30  2021-10-11  1344839   57936  104285580  23060090   82318270  0.043080
# 31  2021-10-12  1240023   40890   77864460  15718145   63040285  0.032975
# 32  2021-10-13  1223064   40011   78578170  15082150   64347910  0.032714
# 33  2021-10-14  1227135   36662   72926170  13821730   60001540  0.029876
# 34  2021-10-15  1311834   37444   83755930  14359670   70431450  0.028543
# 35  2021-10-16  1431063   39170   83111930  14243855   69927375  0.027371
# 36  2021-10-17  1398224   34835   69013010  11912545   58170335  0.024914
#
#           arpu        arppu  account_cnt  ...  nunique_bundle  sum_price  \
# 0    95.929755  2605.737367         3990  ...              28   15518660
# 1    69.256283  2329.377899         3265  ...              27   11959970
# 2    63.489747  2478.762525         2491  ...              28    8810450
# 3    56.637961  2466.885093         2171  ...              26    7723980
# 4    62.630628  2445.878949         2191  ...              27    8180770
# 5    55.882003  2377.199578         2131  ...              27    7976670
# 6   163.565525  2933.656194        35438  ...              30  112402470
# 7    94.829100  2587.377041        17935  ...              31   51924650
# 8    72.756886  2428.532372        12431  ...              31   35212680
# 9    63.420348  2397.476528         9626  ...              29   26969320
# 10   59.171305  2395.709906         8079  ...              30   22103630
# 11   54.470566  2349.019756         6619  ...              30   18697880
# 12   47.013170  2246.611176         5110  ...              30   13867300
# 13   45.916107  2302.507010         4743  ...              29   13217340
# 14   45.543430  2284.976678         4946  ...              30   13783020
# 15   42.226655  2244.112960         3964  ...              31   11100180
# 16   45.779126  2393.528585         3489  ...              30   10476640
# 17   47.868073  1892.497315         3453  ...              29   10531000
# 18   97.937276  1220.032548        13963  ...              43   21639880
# 19   60.540523  1114.066826         8140  ...              43   14921230
# 20   53.083543   986.723584         7216  ...              42   14004520
# 21   48.735430   876.730797         6171  ...              43   12486820
# 22   47.239361   786.810838         5721  ...              43   11777420
# 23   46.963262   746.767148         5243  ...              43   10509230
# 24   47.841977   701.451053         4955  ...              43    9894820
# 25  309.363166  2873.083196         4432  ...              42    8327570
# 26  182.267175  1903.814646         5367  ...              43   10078080
# 27  134.838573  1622.864079         5069  ...              42    9492510
# 28  124.947667  1169.379735         7416  ...              42   12735440
# 29  118.916121  1040.908327         8914  ...              41   15316250
# 30   77.545030  1800.013463         3700  ...              43    7676730
# 31   62.792755  1904.242113         2861  ...              42    6191640
# 32   64.246981  1963.914174         2716  ...              43    5865580
# 33   59.427993  1989.148710         2763  ...              43    5810520
# 34   63.846439  2236.831802         3515  ...              43    7242370
# 35   58.077059  2121.826142         3383  ...              41    7472330
# 36   49.357621  1981.139945         3104  ...              43    6769580
#
#     3000_account_cnt  3000_trans_cnt  3000_nunique_bundle  3000_sum_price  \
# 0               2056            2078                    2        10396980
# 1               1457            1473                    2         7282440
# 2                975             985                    2         5035140
# 3                774             787                    2         4120380
# 4                897             909                    2         4787640
# 5                830             840                    2         4550040
# 6              13291           13487                    3        73594380
# 7               5187            5347                    3        29088540
# 8               3251            3378                    3        18446320
# 9               2364            2456                    3        13528060
# 10              1796            1855                    3        10365340
# 11              1523            1578                    3         8908580
# 12              1093            1136                    3         6260220
# 13              1039            1084                    3         6103780
# 14              1062            1122                    3         6230720
# 15               839             897                    3         4990020
# 16               917             995                    3         5332140
# 17               993            1047                    3         5536780
# 18               934             993                    3         5302200
# 19               690             708                    3         4200320
# 20               584             594                    2         3837920
# 21               513             523                    2         3460600
# 22               487             499                    2         3352340
# 23               409             419                    2         2810100
# 24               402             408                    2         2745800
# 25               307             316                    2         2169500
# 26               370             380                    2         2580100
# 27               341             346                    2         2292560
# 28               359             370                    2         2543540
# 29               453             457                    2         3074800
# 30               279             284                    2         1955280
# 31               226             233                    2         1602020
# 32               225             230                    2         1643680
# 33               222             230                    2         1576780
# 34               264             269                    2         1873680
# 35               307             311                    2         2204740
# 36               265             274                    2         1900880
#
#     account percentage  trans percentage  price percentage  bundle/total
# 0                51.53             47.53             67.00      0.103025
# 1                44.62             41.60             60.89      0.108754
# 2                39.14             36.19             57.15      0.101464
# 3                35.65             32.89             53.35      0.100723
# 4                40.94             38.40             58.52      0.099774
# 5                38.95             36.22             57.04      0.104004
# 6                37.50             36.10             65.47      0.474869
# 7                28.92             28.05             56.02      0.353779
# 8                26.15             25.47             52.39      0.296049
# 9                24.56             23.96             50.16      0.263376
# 10               22.23             21.60             46.89      0.235733
# 11               23.01             22.18             47.64      0.231944
# 12               21.39             20.85             45.14      0.211867
# 13               21.91             21.30             46.18      0.196307
# 14               21.47             21.00             45.21      0.191401
# 15               21.17             21.00             44.95      0.182475
# 16               26.28             25.91             50.90      0.180938
# 17               28.76             27.63             52.58      0.161532
# 18                6.69              6.59             24.50      0.156878
# 19                8.48              8.04             28.15      0.167170
# 20                8.09              7.65             27.40      0.169000
# 21                8.31              7.88             27.71      0.160336
# 22                8.51              8.11             28.46      0.153343
# 23                7.80              7.44             26.74      0.141643
# 24                8.11              7.70             27.75      0.134948
# 25                6.93              6.76             26.05      0.020431
# 26                6.89              6.67             25.60      0.036150
# 27                6.73              6.49             24.15      0.048799
# 28                4.84              4.78             19.97      0.064916
# 29                5.08              4.92             20.08      0.079278
# 30                7.54              7.25             25.47      0.073613
# 31                7.90              7.60             25.87      0.079518
# 32                8.28              7.90             28.02      0.074646
# 33                8.03              7.74             27.14      0.079677
# 34                7.51              7.12             25.87      0.086470
# 35                9.07              8.53             29.51      0.089907
# 36                8.54              8.28             28.08      0.098091
#
# [37 rows x 21 columns]

# %%
pur_daily.round(2)
# Out:
#           date       au      pu  price_sum  free_sum   paid_sum   pur    arpu  \
# 0   2021-09-11  1570210   57807  150629860  28873070  124667770  0.04   95.93
# 1   2021-09-12  1587903   47211  109972260  20820080   91577430  0.03   69.26
# 2   2021-09-13  1367678   35031   86833530  15454890   73133320  0.03   63.49
# 3   2021-09-14  1353961   31086   76685590  13069929   65281031  0.02   56.64
# 4   2021-09-15  1309155   33523   81993200  13806350   69854420  0.03   62.63
# 5   2021-09-16  1372456   32263   76695590  12659150   65581220  0.02   55.88
# 6   2021-09-17  1447139   80685  236702050  36472460  201647860  0.06  163.57
# 7   2021-09-18  1547748   56726  146771550  21961770  126187570  0.04   94.83
# 8   2021-09-19  1634790   48977  118942230  17868050  102419660  0.03   72.76
# 9   2021-09-20  1614602   42711  102398620  15356980   88414320  0.03   63.42
# 10  2021-09-21  1584648   39139   93765690  13703330   81209430  0.02   59.17
# 11  2021-09-22  1479949   34318   80613660  11793130   69979980  0.02   54.47
# 12  2021-09-23  1392222   29134   65452770   9533510   56826210  0.02   47.01
# 13  2021-09-24  1466368   29242   67329910   9612040   58741660  0.02   45.92
# 14  2021-09-25  1581151   31515   72011040  10268360   62789580  0.02   45.54
# 15  2021-09-26  1440587   27107   60831170   8539440   53271680  0.02   42.23
# 16  2021-09-27  1264809   24191   57901850   8310010   50541820  0.02   45.78
# 17  2021-09-28  1361965   34449   65194640  10790840   55360090  0.03   47.87
# 18  2021-09-29  1408458  113063  137940540  26607209  112415291  0.08   97.94
# 19  2021-09-30  1474350   80119   89257920  19168921   71346599  0.05   60.54
# 20  2021-10-01  1561068   83982   82867020  20661000   63570900  0.05   53.08
# 21  2021-10-02  1597998   88829   77879120  23004650   56090140  0.06   48.74
# 22  2021-10-03  1625859   97615   76804540  27081850   51058850  0.06   47.24
# 23  2021-10-04  1579853   99355   74195050  29048710   46457120  0.06   46.96
# 24  2021-10-05  1532616  104531   73323380  32186380   42495970  0.07   47.84
# 25  2021-10-06  1317550  141869  407601440  77771950  330871780  0.11  309.36
# 26  2021-10-07  1529520  146433  278781290  64016030  216198850  0.10  182.27
# 27  2021-10-08  1442636  119864  194522980  48176380  147526740  0.08  134.84
# 28  2021-10-09  1570124  167767  196183330  67472790  130231080  0.11  124.95
# 29  2021-10-10  1624656  185605  193197790  75282140  119551120  0.11  118.92
# 30  2021-10-11  1344839   57936  104285580  23060090   82318270  0.04   77.55
# 31  2021-10-12  1240023   40890   77864460  15718145   63040285  0.03   62.79
# 32  2021-10-13  1223064   40011   78578170  15082150   64347910  0.03   64.25
# 33  2021-10-14  1227135   36662   72926170  13821730   60001540  0.03   59.43
# 34  2021-10-15  1311834   37444   83755930  14359670   70431450  0.03   63.85
# 35  2021-10-16  1431063   39170   83111930  14243855   69927375  0.03   58.08
# 36  2021-10-17  1398224   34835   69013010  11912545   58170335  0.02   49.36
#
#       arppu
# 0   2605.74
# 1   2329.38
# 2   2478.76
# 3   2466.89
# 4   2445.88
# 5   2377.20
# 6   2933.66
# 7   2587.38
# 8   2428.53
# 9   2397.48
# 10  2395.71
# 11  2349.02
# 12  2246.61
# 13  2302.51
# 14  2284.98
# 15  2244.11
# 16  2393.53
# 17  1892.50
# 18  1220.03
# 19  1114.07
# 20   986.72
# 21   876.73
# 22   786.81
# 23   746.77
# 24   701.45
# 25  2873.08
# 26  1903.81
# 27  1622.86
# 28  1169.38
# 29  1040.91
# 30  1800.01
# 31  1904.24
# 32  1963.91
# 33  1989.15
# 34  2236.83
# 35  2121.83
# 36  1981.14

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(15, 10))
ax2 = ax1.twinx()
pur_daily['price_sum'].plot(kind='bar', color='y', ax=ax1)
pur_daily['pur'].plot(kind='line', marker='d', ax=ax2)
ax1.yaxis.tick_right()
ax2.yaxis.tick_left()

# %%
pur_daily.round(2).to_csv('pur_daily.csv', index=False)

# %%
daily_gcoin_pd = gcoin_pc.groupBy('date', 'account_id').agg(sum('price').alias('gcoin_daily_use'), 
                                        min('price').alias('min_gcoin'), 
                                        avg('price').alias('avg_gcoin'), 
                                        max('price').alias('max_gcoin'),
                                        countDistinct('transaction_id').alias('trans_time')).toPandas()

# %%
# 최고치로 예상

# %%
account_cnt_500 = daily_gcoin_pd[(daily_gcoin_pd.gcoin_daily_use >= 500) & (daily_gcoin_pd.gcoin_daily_use < 3000)].groupby('date')['account_id'].count().reset_index(name='500').sort_values('date')
account_cnt_3000= daily_gcoin_pd[(daily_gcoin_pd.gcoin_daily_use >= 3000) & (daily_gcoin_pd.gcoin_daily_use < 5000)].groupby('date')['account_id'].count().reset_index(name='3000').sort_values('date')
account_cnt_5000 = daily_gcoin_pd[daily_gcoin_pd.gcoin_daily_use >= 5000].groupby('date')['account_id'].count().reset_index(name='5000').sort_values('date')

# %%
a = pd.merge(account_cnt_500, account_cnt_3000, on='date')
a = pd.merge(a, account_cnt_5000, on='date')
a.head()
# Out:
#          date    500  3000  5000
# 0  2021-09-11  36578  4746  6199
# 1  2021-09-12  29476  3636  4421
# 2  2021-09-13  21245  2522  3486
# 3  2021-09-14  18356  2150  3056
# 4  2021-09-15  18739  2325  3448

# %%
a['emote'] = a['500'] * 4.99
a['bundle'] = a['3000'] * 31.99
a['mega'] = a['5000'] * 59.99

# %%
a[['emote', 'bundle', 'mega']].sum()
# Out:
# emote     5282663.50
# bundle    2945479.25
# mega      9978436.65
# dtype: float64

# %%
a[['emote', 'bundle', 'mega']].sum().values.sum()
# Out:
# 18206579.4

# %%
a.to_csv('pc_predicted_max.csv', index=False)

# %%
# 최저치 예상

# %%
account_cnt_emote = daily_gcoin_pd[(daily_gcoin_pd.gcoin_daily_use >= 500) & (daily_gcoin_pd.gcoin_daily_use < 1000)].groupby('date')['account_id'].count().reset_index(name='500').sort_values('date')
account_cnt_bundle = daily_gcoin_pd[(daily_gcoin_pd.gcoin_daily_use >= 3000) & (daily_gcoin_pd.gcoin_daily_use < 3500)].groupby('date')['account_id'].count().reset_index(name='3000').sort_values('date')
account_cnt_mega = daily_gcoin_pd[(daily_gcoin_pd.gcoin_daily_use >= 5500)].groupby('date')['account_id'].count().reset_index(name='5500').sort_values('date')

# %%
b = pd.merge(account_cnt_emote, account_cnt_bundle, on='date')
b = pd.merge(b, account_cnt_mega, on='date')
b.head()
# Out:
#          date    500  3000  5500
# 0  2021-09-11  21948  1495  5194
# 1  2021-09-12  17729  1200  3612
# 2  2021-09-13  12501   811  2910
# 3  2021-09-14  10853   685  2563
# 4  2021-09-15  10764   691  2846

# %%
b['emote'] = b['500'] * 4.99
b['bundle'] = b['3000'] * 31.99
b['mega'] = b['5500'] * 59.99

# %%
b[['emote', 'bundle', 'mega']].sum()
# Out:
# emote     3101424.72
# bundle     933436.21
# mega      7462935.97
# dtype: float64

# %%
b[['emote', 'bundle', 'mega']].sum().values.sum()
# Out:
# 11497796.900000002

# %%
b.to_csv('pc_predicted_min.csv', index=False)

# %%
pur_weekly = pd.merge(pc_au_weekly_pd, pc_gcoin_weekly_pd, on='week')

# %%
pur_weekly['pur'] = pur_weekly.pu/pur_weekly.au
pur_weekly['arpu'] = pur_weekly.au/pur_weekly.price_sum
pur_weekly['arppu'] = pur_weekly.pu/pur_weekly.price_sum

# %%
pur_weekly
# Out:
#     week       au      pu   price_sum   free_sum   paid_sum       pur  \
# 0  week1  3516815  246487   819512080  141155929  691743051  0.070088
# 1  week2  3769736  227062   675274430   99828810  583778830  0.060233
# 2  week3  3547309  314815   566004180  104345780  469295960  0.088748
# 3  week4  3612634  552997  1183107800  301285950  890699450  0.153073
# 4  week5  3254344  491315   806791430  224796715  589921655  0.150972
# 5  week6  2003704   71020   152124940   26156400  128097710  0.035444
#
#        arpu     arppu
# 0  0.004291  0.000301
# 1  0.005583  0.000336
# 2  0.006267  0.000556
# 3  0.003054  0.000467
# 4  0.004034  0.000609
# 5  0.013171  0.000467

# %%
# df_meta = mysql.read_table(spark, 'metainfo', 'item_meta_sales')
# df_meta.show(5, False)
